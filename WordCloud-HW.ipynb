# %% [markdown]
# ## 安裝套件

# %%
# !pip install -q requests

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=297d848f66804d80ba674eb0b3abdc85137da58e4362a4a96d556f014d0cb309
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 4.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lxml
# Successfully installed lxml-4.9.2

# %%
# !pip install jieba
# Out:
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 4.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314458 sha256=aaa3e9c611690afe433683569d28bdd9ff4677ea92ea21ba8b563beda9c66388
#   Stored in directory: /home/jovyan/.cache/pip/wheels/c9/69/31/d56d90b22a1777b0b231e234b00302a55be255930f8bd92dcd
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %% [markdown]
# ### 下載繁體字的辭典檔

# %%
# !wget https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big -O jieba_data/dict.txt.big
# Out:
# --2023-04-24 16:14:05--  https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big
# Resolving github.com (github.com)... 20.27.177.113, ::ffff:20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big [following]
# --2023-04-24 16:14:06--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... ::ffff:185.199.111.133, ::ffff:185.199.109.133, ::ffff:185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|::ffff:185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘jieba_data/dict.txt.big’
#
# jieba_data/dict.txt 100%[===================>]   8.18M  5.56MB/s    in 1.5s
#
# 2023-04-24 16:14:09 (5.56 MB/s) - ‘jieba_data/dict.txt.big’ saved [8583143/8583143]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %% [markdown]
# ## 解析 RSS

# %%
import feedparser

# %%
#rss_url = "https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money"

# %%
rss_url = "https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money"

# %%
newsFeed = feedparser.parse(rss_url)
newsFeed
# Out:
# {'bozo': False,
#  'entries': [{'title': '盧沙野惹眾怒 近80歐洲議員籲列為不受歡迎人物',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '盧沙野惹眾怒 近80歐洲議員籲列為不受歡迎人物'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119684'}],
#    'link': 'https://money.udn.com/money/story/5599/7119684',
#    'published': 'Mon, 24 Apr 2023 15:36:18 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=7, tm_min=36, tm_sec=18, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '中國駐法國大使盧沙野近日的公開發言引發爭議，近80名歐洲議員在法國「世界報」發表公開信，呼籲法國外交部長柯隆納（Cath...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '中國駐法國大使盧沙野近日的公開發言引發爭議，近80名歐洲議員在法國「世界報」發表公開信，呼籲法國外交部長柯隆納（Cath...'},
#    'id': 'https://money.udn.com/money/story/5599/7119684',
#    'guidislink': False},
#   {'title': '為選總統暖身 佛州長出訪首站抵日與岸田相見歡',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '為選總統暖身 佛州長出訪首站抵日與岸田相見歡'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119685'}],
#    'link': 'https://money.udn.com/money/story/5599/7119685',
#    'published': 'Mon, 24 Apr 2023 15:36:18 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=7, tm_min=36, tm_sec=18, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '各界預期可能參選美國總統的佛羅里達州長迪尚特（Ron DeSantis）今天在東京展開國際訪問行程時，盛讚日本強化國防之...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '各界預期可能參選美國總統的佛羅里達州長迪尚特（Ron DeSantis）今天在東京展開國際訪問行程時，盛讚日本強化國防之...'},
#    'id': 'https://money.udn.com/money/story/5599/7119685',
#    'guidislink': False},
#   {'title': '鐵礦砂價格又面臨100美元保衛戰 因大陸鋼鐵需求疲弱',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '鐵礦砂價格又面臨100美元保衛戰 因大陸鋼鐵需求疲弱'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119632'}],
#    'link': 'https://money.udn.com/money/story/5599/7119632',
#    'published': 'Mon, 24 Apr 2023 15:14:12 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=7, tm_min=14, tm_sec=12, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21379844.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=3303&amp;sh=2184&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>鐵礦砂期貨價格跌至去年12月初以來最低水準，因需求持續疲軟繼續拖累整體市場情緒。</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21379844.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=3303&amp;sh=2184&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>鐵礦砂期貨價格跌至去年12月初以來最低水準，因需求持續疲軟繼續拖累整體市場情緒。</p>'},
#    'id': 'https://money.udn.com/money/story/5599/7119632',
#    'guidislink': False},
#   {'title': '德州小鎮中學派對爆槍擊 9青少年受傷',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '德州小鎮中學派對爆槍擊 9青少年受傷'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119603'}],
#    'link': 'https://money.udn.com/money/story/5599/7119603',
#    'published': 'Mon, 24 Apr 2023 15:00:16 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=7, tm_min=0, tm_sec=16, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '警方表示，德州賈斯坡（Jasper）鎮今晨發生槍擊，9名參加畢業舞會後續攤派對的青少年受傷。警方本週將在小鎮的中學加派警...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '警方表示，德州賈斯坡（Jasper）鎮今晨發生槍擊，9名參加畢業舞會後續攤派對的青少年受傷。警方本週將在小鎮的中學加派警...'},
#    'id': 'https://money.udn.com/money/story/5599/7119603',
#    'guidislink': False},
#   {'title': '台灣素食料理為親善橋梁 名廚黃景龍英國獻藝',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '台灣素食料理為親善橋梁 名廚黃景龍英國獻藝'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119588'}],
#    'link': 'https://money.udn.com/money/story/5599/7119588',
#    'published': 'Mon, 24 Apr 2023 14:54:17 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=54, tm_sec=17, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '台菜名廚黃景龍近日在英國演繹台灣素食料理，功力讓本地專業廚師讚賞。策劃活動的僑委會國際青年親善大使謝優康說，飲食超越語言...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '台菜名廚黃景龍近日在英國演繹台灣素食料理，功力讓本地專業廚師讚賞。策劃活動的僑委會國際青年親善大使謝優康說，飲食超越語言...'},
#    'id': 'https://money.udn.com/money/story/5599/7119588',
#    'guidislink': False},
#   {'title': '澳洲二戰來最大規模國防調整 優先發展長程打擊',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '澳洲二戰來最大規模國防調整 優先發展長程打擊'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119589'}],
#    'link': 'https://money.udn.com/money/story/5599/7119589',
#    'published': 'Mon, 24 Apr 2023 14:54:16 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=54, tm_sec=16, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '今天發布的「國防戰略檢討」報告建議澳洲進行第二次世界大戰以來最大規模的國防策略調整，將長程精準打擊，國內生產導引武器及外...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '今天發布的「國防戰略檢討」報告建議澳洲進行第二次世界大戰以來最大規模的國防策略調整，將長程精準打擊，國內生產導引武器及外...'},
#    'id': 'https://money.udn.com/money/story/5599/7119589',
#    'guidislink': False},
#   {'title': '延續華爾街溫和漲勢 日股收高',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '延續華爾街溫和漲勢 日股收高'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119567'}],
#    'link': 'https://money.udn.com/money/story/5599/7119567',
#    'published': 'Mon, 24 Apr 2023 14:45:17 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=45, tm_sec=17, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '投資人等待日本和美國企業財報季之際，東京股市今天延續華爾街上週的溫和漲勢收高',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '投資人等待日本和美國企業財報季之際，東京股市今天延續華爾街上週的溫和漲勢收高'},
#    'id': 'https://money.udn.com/money/story/5599/7119567',
#    'guidislink': False},
#   {'title': '研究：氣候研究報導恐致反效果 無助解決問題',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '研究：氣候研究報導恐致反效果 無助解決問題'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119566'}],
#    'link': 'https://money.udn.com/money/story/5599/7119566',
#    'published': 'Mon, 24 Apr 2023 14:45:17 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=45, tm_sec=17, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '瑞士研究顯示，媒體對氣候研究的報導大多可能無助於促進解決問題所需的友善環境行為，反而讓人無所作為',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '瑞士研究顯示，媒體對氣候研究的報導大多可能無助於促進解決問題所需的友善環境行為，反而讓人無所作為'},
#    'id': 'https://money.udn.com/money/story/5599/7119566',
#    'guidislink': False},
#   {'title': '即將走入歷史 瑞士信貸淨資產流出迄未停止',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '即將走入歷史 瑞士信貸淨資產流出迄未停止'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119553'}],
#    'link': 'https://money.udn.com/money/story/5599/7119553',
#    'published': 'Mon, 24 Apr 2023 14:41:44 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=41, tm_sec=44, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21379020.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=5109&amp;sh=3406&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>瑞士信貸（Credit Suisse）公布第1季淨資產流出610億瑞士法郎（680億美元），雖已接受瑞銀集團（UBS）由...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21379020.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=5109&amp;sh=3406&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>瑞士信貸（Credit Suisse）公布第1季淨資產流出610億瑞士法郎（680億美元），雖已接受瑞銀集團（UBS）由...</p>'},
#    'id': 'https://money.udn.com/money/story/5599/7119553',
#    'guidislink': False},
#   {'title': '資方不信遠端辦公效率 線上監控員工趨普遍',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '資方不信遠端辦公效率 線上監控員工趨普遍'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119544'}],
#    'link': 'https://money.udn.com/money/story/5599/7119544',
#    'published': 'Mon, 24 Apr 2023 14:36:21 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=36, tm_sec=21, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '過去幾年遠端或居家工作因COVID-19疫情而興起，但職場上雇主透過監控軟體「監督」卻有變本加厲情況，員工「不爽」而消極...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '過去幾年遠端或居家工作因COVID-19疫情而興起，但職場上雇主透過監控軟體「監督」卻有變本加厲情況，員工「不爽」而消極...'},
#    'id': 'https://money.udn.com/money/story/5599/7119544',
#    'guidislink': False},
#   {'title': '6年來犯案超過500次！美佛州迪士尼員工「偷拍女性」遭捕',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '6年來犯案超過500次！美佛州迪士尼員工「偷拍女性」遭捕'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119493'}],
#    'link': 'https://money.udn.com/money/story/5599/7119493',
#    'published': 'Mon, 24 Apr 2023 14:17:32 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=17, tm_sec=32, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21378685.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=3000&amp;sh=2011&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>一名前迪士尼樂園員工面臨指控稱他偷拍女性顧客的裙底風光，被捕後更向調查人員供稱自己過去6年裡偷拍了超過500次。</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21378685.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=3000&amp;sh=2011&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>一名前迪士尼樂園員工面臨指控稱他偷拍女性顧客的裙底風光，被捕後更向調查人員供稱自己過去6年裡偷拍了超過500次。</p>'},
#    'id': 'https://money.udn.com/money/story/5599/7119493',
#    'guidislink': False},
#   {'title': '墨西哥總統3度感染COVID 身體狀況良好',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '墨西哥總統3度感染COVID 身體狀況良好'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119475'}],
#    'link': 'https://money.udn.com/money/story/5599/7119475',
#    'published': 'Mon, 24 Apr 2023 14:12:31 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=6, tm_min=12, tm_sec=31, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '墨西哥總統羅培茲歐布拉多今天表示自己COVID-19（2019冠狀病毒疾病）篩檢呈陽性，這是目前所知第3次染疫，儘管症狀...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '墨西哥總統羅培茲歐布拉多今天表示自己COVID-19（2019冠狀病毒疾病）篩檢呈陽性，這是目前所知第3次染疫，儘管症狀...'},
#    'id': 'https://money.udn.com/money/story/5599/7119475',
#    'guidislink': False},
#   {'title': '規模7.1強震襲紐西蘭附近海域  無海嘯威脅',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '規模7.1強震襲紐西蘭附近海域  無海嘯威脅'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119398'}],
#    'link': 'https://money.udn.com/money/story/5599/7119398',
#    'published': 'Mon, 24 Apr 2023 13:51:23 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=5, tm_min=51, tm_sec=23, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '規模7.1強震今天襲擊紐西蘭附近的克馬得群島（KermadecIslands）海域，紐西蘭無海嘯威脅',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '規模7.1強震今天襲擊紐西蘭附近的克馬得群島（KermadecIslands）海域，紐西蘭無海嘯威脅'},
#    'id': 'https://money.udn.com/money/story/5599/7119398',
#    'guidislink': False},
#   {'title': '秘魯前總統托雷多引渡回國入獄  涉貪汙指控',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '秘魯前總統托雷多引渡回國入獄  涉貪汙指控'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119396'}],
#    'link': 'https://money.udn.com/money/story/5599/7119396',
#    'published': 'Mon, 24 Apr 2023 13:51:23 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=5, tm_min=51, tm_sec=23, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '秘魯前總統托雷多（Alejandro Toledo）今天被移送入獄，數小時前他剛從美國被引渡返回母國秘魯，遭指控在總統任...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '秘魯前總統托雷多（Alejandro Toledo）今天被移送入獄，數小時前他剛從美國被引渡返回母國秘魯，遭指控在總統任...'},
#    'id': 'https://money.udn.com/money/story/5599/7119396',
#    'guidislink': False},
#   {'title': '路透：特斯拉準備將上海廠 Model Y 賣到加拿大',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '路透：特斯拉準備將上海廠 Model Y 賣到加拿大'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119381'}],
#    'link': 'https://money.udn.com/money/story/5599/7119381',
#    'published': 'Mon, 24 Apr 2023 13:46:02 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=5, tm_min=46, tm_sec=2, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21378206.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=6393&amp;sh=4262&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>路透引述知情人士報導，特斯拉（Tesla）今年已開始在上海生產專供外銷加拿大的Model Y ，這將特斯拉首度向北美外銷...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2023/04/24/realtime/21378206.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=6393&amp;sh=4262&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>路透引述知情人士報導，特斯拉（Tesla）今年已開始在上海生產專供外銷加拿大的Model Y ，這將特斯拉首度向北美外銷...</p>'},
#    'id': 'https://money.udn.com/money/story/5599/7119381',
#    'guidislink': False},
#   {'title': '印度首都街頭賽馬車 嚇壞路人10嫌被捕',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '印度首都街頭賽馬車 嚇壞路人10嫌被捕'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119376'}],
#    'link': 'https://money.udn.com/money/story/5599/7119376',
#    'published': 'Mon, 24 Apr 2023 13:45:16 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=5, tm_min=45, tm_sec=16, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '印度首都德里街頭出現賽馬車場景，其中一輛馬車失控撞上路邊障礙物，嚇壞許多路人，德里警方已以虐待動物以及危害交通安全等罪名...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '印度首都德里街頭出現賽馬車場景，其中一輛馬車失控撞上路邊障礙物，嚇壞許多路人，德里警方已以虐待動物以及危害交通安全等罪名...'},
#    'id': 'https://money.udn.com/money/story/5599/7119376',
#    'guidislink': False},
#   {'title': '中國國防部：中星4月下旬舉行海上聯合軍演',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '中國國防部：中星4月下旬舉行海上聯合軍演'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119324'}],
#    'link': 'https://money.udn.com/money/story/5599/7119324',
#    'published': 'Mon, 24 Apr 2023 13:21:31 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=5, tm_min=21, tm_sec=31, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '中國國防部今天公布，中國與新加坡將於4月下旬至5月上旬舉行海上聯合軍演，中國解放軍將派出兩艘軍艦參加',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '中國國防部今天公布，中國與新加坡將於4月下旬至5月上旬舉行海上聯合軍演，中國解放軍將派出兩艘軍艦參加'},
#    'id': 'https://money.udn.com/money/story/5599/7119324',
#    'guidislink': False},
#   {'title': '印尼總統參選人明朗 選戰可能三強鼎立',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '印尼總統參選人明朗 選戰可能三強鼎立'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119266'}],
#    'link': 'https://money.udn.com/money/story/5599/7119266',
#    'published': 'Mon, 24 Apr 2023 13:00:43 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=5, tm_min=0, tm_sec=43, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '印尼2024年2月舉行總統大選，隨著執政黨提名中爪哇省長甘查爾參選，角逐者日漸明朗。除了甘查爾，雅加達前省長阿尼斯獲國家...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '印尼2024年2月舉行總統大選，隨著執政黨提名中爪哇省長甘查爾參選，角逐者日漸明朗。除了甘查爾，雅加達前省長阿尼斯獲國家...'},
#    'id': 'https://money.udn.com/money/story/5599/7119266',
#    'guidislink': False},
#   {'title': '65萬根菸屁股堆成山 氣候人士籲重視菸蒂汙染',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '65萬根菸屁股堆成山 氣候人士籲重視菸蒂汙染'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119250'}],
#    'link': 'https://money.udn.com/money/story/5599/7119250',
#    'published': 'Mon, 24 Apr 2023 12:51:34 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=4, tm_min=51, tm_sec=34, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '環保人士今天在葡萄牙首都里斯本市中心將65萬根菸蒂堆成一座小山，希望喚起人們對長期被忽略的菸蒂污染問題的關注',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '環保人士今天在葡萄牙首都里斯本市中心將65萬根菸蒂堆成一座小山，希望喚起人們對長期被忽略的菸蒂污染問題的關注'},
#    'id': 'https://money.udn.com/money/story/5599/7119250',
#    'guidislink': False},
#   {'title': '歐洲環保署：空污每年導致1200名未成年人早死',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '歐洲環保署：空污每年導致1200名未成年人早死'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/5599/7119234'}],
#    'link': 'https://money.udn.com/money/story/5599/7119234',
#    'published': 'Mon, 24 Apr 2023 12:45:35 +0800',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=4, tm_min=45, tm_sec=35, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'summary': '歐洲環保署（EEA）今天表示，空氣污染每年導致歐洲1200多名18歲以下民眾過早死亡，同時也增加日後罹患慢性病的風險',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#     'value': '歐洲環保署（EEA）今天表示，空氣污染每年導致歐洲1200多名18歲以下民眾過早死亡，同時也增加日後罹患慢性病的風險'},
#    'id': 'https://money.udn.com/money/story/5599/7119234',
#    'guidislink': False}],
#  'feed': {'title': '經濟日報：不僅新聞速度 更有脈絡深度',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#    'value': '經濟日報：不僅新聞速度 更有脈絡深度'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://money.udn.com'}],
#   'link': 'https://money.udn.com',
#   'subtitle': '經濟日報每日提供除產業、股市、金融、國際、彭博及專欄等即時財經新聞，並針對重要議題製作去碎片、有脈絡的深度內容，提供解讀、分析、整理、精選專題、專家觀點等，幫助讀者擺脫資訊碎片化的困擾。',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#    'value': '經濟日報每日提供除產業、股市、金融、國際、彭博及專欄等即時財經新聞，並針對重要議題製作去碎片、有脈絡的深度內容，提供解讀、分析、整理、精選專題、專家觀點等，幫助讀者擺脫資訊碎片化的困擾。'},
#   'published': 'Mon, 24 Apr 2023 15:56:38 +0800',
#   'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=24, tm_hour=7, tm_min=56, tm_sec=38, tm_wday=0, tm_yday=114, tm_isdst=0),
#   'rights': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#    'value': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.'},
#   'language': 'zh-TW',
#   'ttl': '10'},
#  'headers': {'content-encoding': 'gzip',
#   'access-control-allow-credentials': 'true',
#   'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000',
#   'content-type': 'text/xml;charset=UTF-8',
#   'date': 'Mon, 24 Apr 2023 08:14:13 GMT',
#   'ec-r22-2-1': 'money',
#   'ec-version': 'All-Policy-20230113',
#   'server': 'nginx',
#   'service-worker-allowed': '/',
#   'via': '1.1 google',
#   'x-e': 'cl-mo-c3p7',
#   'x-mhn': 'money-ci3-69d54975f6-472vv',
#   'transfer-encoding': 'chunked',
#   'connection': 'close'},
#  'href': 'https://money.udn.com/rssfeed/news/1001/5588/5599?ch=money',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {}}

# %% [markdown]
# ### 查看每個 entry 的 title, url

# %%
i = 1
for e in newsFeed['entries']:
    title = e['title']
    link_url = e['links'][0]['href']
    print("%s, %s, %s"%(i, title, link_url))
    i = i + 1
# Out:
# 1, 盧沙野惹眾怒 近80歐洲議員籲列為不受歡迎人物, https://money.udn.com/money/story/5599/7119684
# 2, 為選總統暖身 佛州長出訪首站抵日與岸田相見歡, https://money.udn.com/money/story/5599/7119685
# 3, 鐵礦砂價格又面臨100美元保衛戰 因大陸鋼鐵需求疲弱, https://money.udn.com/money/story/5599/7119632
# 4, 德州小鎮中學派對爆槍擊 9青少年受傷, https://money.udn.com/money/story/5599/7119603
# 5, 台灣素食料理為親善橋梁 名廚黃景龍英國獻藝, https://money.udn.com/money/story/5599/7119588
# 6, 澳洲二戰來最大規模國防調整 優先發展長程打擊, https://money.udn.com/money/story/5599/7119589
# 7, 延續華爾街溫和漲勢 日股收高, https://money.udn.com/money/story/5599/7119567
# 8, 研究：氣候研究報導恐致反效果 無助解決問題, https://money.udn.com/money/story/5599/7119566
# 9, 即將走入歷史 瑞士信貸淨資產流出迄未停止, https://money.udn.com/money/story/5599/7119553
# 10, 資方不信遠端辦公效率 線上監控員工趨普遍, https://money.udn.com/money/story/5599/7119544
# 11, 6年來犯案超過500次！美佛州迪士尼員工「偷拍女性」遭捕, https://money.udn.com/money/story/5599/7119493
# 12, 墨西哥總統3度感染COVID 身體狀況良好, https://money.udn.com/money/story/5599/7119475
# 13, 規模7.1強震襲紐西蘭附近海域  無海嘯威脅, https://money.udn.com/money/story/5599/7119398
# 14, 秘魯前總統托雷多引渡回國入獄  涉貪汙指控, https://money.udn.com/money/story/5599/7119396
# 15, 路透：特斯拉準備將上海廠 Model Y 賣到加拿大, https://money.udn.com/money/story/5599/7119381
# 16, 印度首都街頭賽馬車 嚇壞路人10嫌被捕, https://money.udn.com/money/story/5599/7119376
# 17, 中國國防部：中星4月下旬舉行海上聯合軍演, https://money.udn.com/money/story/5599/7119324
# 18, 印尼總統參選人明朗 選戰可能三強鼎立, https://money.udn.com/money/story/5599/7119266
# 19, 65萬根菸屁股堆成山 氣候人士籲重視菸蒂汙染, https://money.udn.com/money/story/5599/7119250
# 20, 歐洲環保署：空污每年導致1200名未成年人早死, https://money.udn.com/money/story/5599/7119234

# %% [markdown]
# ### 解析html可以參考 https://lxml.de/lxmlhtml.html

# %% [markdown]
# ## 開始取得文章

# %% [markdown]
# ### 載入 library

# %%
import requests
from lxml import etree
from io import StringIO
import jieba
import pandas as pd
import time
import random

# %% [markdown]
# ### 使用繁體辭典

# %%
#指定辭典檔
jieba.set_dictionary('jieba_data/dict.txt.big')

# %% [markdown]
# ### 設定 request header

# %%
#設定 request header
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
my_headers = {
    'User-Agent': user_agent,
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "accept-encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "cache-control": "no-cache",
    "Accept-Charset": "UTF8,utf-8;q=0.7,*;q=0.7"
}

# %% [markdown]
# ### 先爬文

# %%
#分解動作

#爬文
each_article_text_list = []
for e in newsFeed['entries']:
    url = e['links'][0]['href']
    print(url)
    r = requests.get(url, headers = my_headers)
    if r.status_code == 200:
        parse_tree = etree.parse(StringIO(r.text), etree.HTMLParser())
        article_elements = parse_tree.xpath('//*[@id="article_body"]//p')
        for a_part in article_elements:
            if type(a_part.text) is str:
                each_article_text_list.append(a_part.text.strip())
        sleep_time = random.randint(3,10)
        print("sleep time: %s sec"%(sleep_time))
        time.sleep(sleep_time)
    all_article_text = ''.join(each_article_text_list)
all_article_text
# Out:
# https://money.udn.com/money/story/5599/7119684
# sleep time: 6 sec
# https://money.udn.com/money/story/5599/7119685
# sleep time: 8 sec
# https://money.udn.com/money/story/5599/7119632
# sleep time: 8 sec
# https://money.udn.com/money/story/5599/7119603
# sleep time: 8 sec
# https://money.udn.com/money/story/5599/7119588
# sleep time: 9 sec
# https://money.udn.com/money/story/5599/7119589
# sleep time: 5 sec
# https://money.udn.com/money/story/5599/7119567
# sleep time: 9 sec
# https://money.udn.com/money/story/5599/7119566
# sleep time: 8 sec
# https://money.udn.com/money/story/5599/7119553
# sleep time: 6 sec
# https://money.udn.com/money/story/5599/7119544
# sleep time: 5 sec
# https://money.udn.com/money/story/5599/7119493
# sleep time: 9 sec
# https://money.udn.com/money/story/5599/7119475
# sleep time: 5 sec
# https://money.udn.com/money/story/5599/7119398
# sleep time: 9 sec
# https://money.udn.com/money/story/5599/7119396
# sleep time: 6 sec
# https://money.udn.com/money/story/5599/7119381
# sleep time: 8 sec
# https://money.udn.com/money/story/5599/7119376
# sleep time: 6 sec
# https://money.udn.com/money/story/5599/7119324
# sleep time: 6 sec
# https://money.udn.com/money/story/5599/7119266
# sleep time: 7 sec
# https://money.udn.com/money/story/5599/7119250
# sleep time: 4 sec
# https://money.udn.com/money/story/5599/7119234
# sleep time: 5 sec
# '中國駐法國大使盧沙野近日的公開發言引發爭議，近80名歐洲議員在法國「世界報」發表公開信，呼籲法國外交部長柯隆納（Catherine Colonna）宣布將盧沙野列為不受歡迎人物。綜合媒體報導，盧沙野近日接受法媒訪問時指「前蘇聯國家並無主權國地位」、「克里米亞半島是俄羅斯的一部分」，相關言論不但惹怒烏克蘭及波羅的海三國，也引發歐盟與法國政界的不滿。近80名歐洲議員23日在法國世界報（Le Monde）發表公開信表示，盧沙野的激進言論嚴重侮辱相關國家的歷史、文化及完整性，並且明顯違反國際法，必須視為對法國歐洲夥伴國家安全的威脅。公開信強調，「不管是中國，或任何其他國家，無權質疑他國的主權。主權不是一個外交玩具，而是國際關係、國際法和『聯合國憲章』的基本要素」。這封公開信中形容，盧沙野的言論是最糟糕的「戰狼」行徑，完全超出外交辭令可接受的範疇。特別是在俄羅斯侵犯烏克蘭令歐洲陷入戰火之際，民主世界必須態度堅定地捍衛盟友主權。這些歐洲議員呼籲柯隆納將盧沙野列為「不受歡迎人物」。盧沙野21日接受法國LCI新聞台訪問，主持人問說「克里米亞是否屬於烏克蘭」，盧沙野回答，「不一定，取決我們如何看待這些問題…沒有這麼簡單」。主持人提醒，根據國際法，克里米亞屬於烏克蘭。盧沙野卻說，「根據國際法，這些前蘇聯國家沒有有效地位，因為沒有國際協議以具體化他們的主權國家地位」。包括烏克蘭在內的多個歐洲國家批評盧沙野言論荒謬，要求中方澄清。各界預期可能參選美國總統的佛羅里達州長迪尚特（Ron DeSantis）今天在東京展開國際訪問行程時，盛讚日本強化國防之舉。法新社報導，外界普遍預期共和黨籍的迪尚特明年將尋求黨內總統候選人提名，而他此次訪問日本、韓國、以色列與英國，一般認為是替自己的外交和安全資歷增色。迪尚特今天在正式會談前告訴日本首相岸田文雄，「我們非常稱許您強化國防的努力」。迪尚特指的是日本當局改革安全策略和提高國防支出的決定。按照官方說法，迪尚特此次出訪，是替佛州創造商業機會，迪尚特今天也不忘吹捧佛州的經濟吸引力。他告訴岸田：「我們注意到，我們是沒有直飛日本航班的全美最大市場。」他說，希望與航空公司會面，「嘗試為此做點什麼」。日本在國防上依賴華盛頓，其領導人將密切關注明年的美國總統大選，無論誰入主白宮，日本都渴望確保兩國邦誼穩固。岸田告訴迪尚特，希望這次訪問，能讓迪尚特「更加了解日本政治、經濟和文化」。日本上月於佛州在民族英雄大谷翔平帶領下抱回世界棒球經典賽冠軍，迪尚特也向岸田道賀。迪尚特說：「真希望我們有大谷，但那也是沒辦法的事。」迪尚特今晚將與日本外務大臣林芳正共進晚餐，之後啟程飛往韓國首爾。鐵礦砂期貨價格跌至去年12月初以來最低水準，因需求持續疲軟繼續拖累整體市場情緒。新加坡鐵礦砂期貨24日盤中重挫4.7%，報每噸103美元，從上周五（14日）迄今重挫超過11%。儘管中國大陸正處於建築業傳統旺季，但鋼鐵消費並未大幅提高，這使得投資人重新評估鐵礦砂市場的復甦時程。大陸華泰期貨表示，雖然鋼廠本周可能會在五一黃金周假期前補充原物料，但除此之外的需求看起來較為溫和，這將限制鋼廠的獲利能力，而且可能導致減產。在供應面方面，全球第四大鐵礦砂生產商Fortescue金屬集團在今年第1季產量持平，但旗下新的鐵礦砂生產項目Iron Bridge Magnetite已投產，在需求沒有跟上的情況下，又有新的供應量增加。大連鐵礦砂期貨24日盤中重挫3.5%至每噸人民幣718.5元。上海螺紋鋼和熱軋卷板期貨都下跌超過2%，在五個月低點附近波動。由於市場擔心中國大陸經濟的復甦步伐，基礎金屬價格也承受壓力。倫敦金屬交易所銅、鋁、鋅、鎳價均走弱。警方表示，德州賈斯坡（Jasper）鎮今晨發生槍擊，9名參加畢業舞會後續攤派對的青少年受傷。警方本週將在小鎮的中學加派警力維安。路透社報導，賈斯坡鎮位於休斯頓（Houston）東北約215公里，居民約7200人。事發地點在鎮上的一處民宅。賈斯坡郡警局指出，傷者均無生命危險，分別送往兩家醫院，但沒說槍手有幾人等細節；警方聲明稱「全案正在調查，已帶回關係人偵訊」。當地KBMT-KJAC電視新聞報導，傷者年齡從15歲到19歲不等。報導稱賈斯坡高中22日晚間在教堂會議廳舉行畢業舞會，但槍擊是發生在舞會後的續攤派對。一週前，在阿拉巴馬州達德維爾（Dadeville）小鎮一場「甜蜜16歲」慶生派對中也發生槍擊案，造成4死32傷；5名犯嫌被控殺人罪。美國疾病管制暨預防中心（CDC）去年指出，槍支已成為美國兒少致死的主要原因，超過機車肇事。美國廣播公司新聞網（ABC News）報導，賈斯坡鎮稍晚又傳出第2起槍擊，警方不排兩起槍擊案之間可能有關聯。台菜名廚黃景龍近日在英國演繹台灣素食料理，功力讓本地專業廚師讚賞。策劃活動的僑委會國際青年親善大使謝優康說，飲食超越語言文化藩籬、貼近人心，是連結台、英最佳橋梁之一。僑務委員會去年首次選拔國際青年親善大使，在英國出生成長、父母來自台灣的謝優康（Oliver Hsieh）是全球18位獲選青年之一。21歲的他目前是英國杜倫大學（Durham University）工程學碩士生。他接受中央社採訪時說，台灣素食料理很有特色，包括英國在內的西方國家近期有吃素潮流，因此嘗試透過素食向英國民眾「推銷台灣」。他說，特別的成長背景讓他相對容易換位思考，理解台英雙方的觀點、思維和情感，這有助他搭建台、英交流橋梁以及從英國視角看台灣。「要有效宣傳，就不能只從台灣人的角度看台灣」，謝優康曾舉辦結合英式下午茶與台灣茶點的文化親善活動；22日「世界地球日」，他在曼徹斯特舉辦台灣素食體驗會，邀請黃景龍掌廚，推出由10道料理組成的自助餐，另附鳳梨酥、珍珠奶茶等代表性甜點，黃景龍現場簡單示範幾道餐點的料理步驟。入場券12英鎊（約新台幣457元）起跳，菜單涵蓋素漢堡肉小農梅干菜割包、素鴨割包、素羊肉蔬菜湯、植物肉燥炒米粉、五柳甜椒紫菜素魚、糖醋鳳梨炸素魚條、素鵝羅漢、涼泮素鴨絲、香素春卷、素叉燒麻油米糕等現做料理。根據活動網站，部分票券收益將捐助聯合國人道事務協調廳（UNOCHA）旗下急難救助計畫，協助土耳其與敘利亞地震災民。午餐、晚餐兩場素食體驗活動總計超過300人參加，其中不屬於亞裔社群的英國本地民眾占近5成，市議員裴柏（Teresa Peppe）和夏沛（Rob Sharpe）應邀出席。前來一嚐台灣素食的義大利裔專業廚師寇提塞（Antonio Cortese）特別喜愛「吃再多也不脹氣」的植物肉燥炒米粉，自稱可一次吃掉至少5人份。他告訴中央社，台灣素食十分具國際競爭力，問題只在何時能形成旋風、在國際間取得可觀商業成果。隨著素食在各國的市場接受度和需求提升，可期待台灣素食的國際舞台擴大。有20年餐廳營運經驗、曾參與電視節目料理示範的希臘裔廚師艾斯丁（Solos Astin）告訴中央社，台灣素食有本事提供廣大美食愛好者與含肉料理同樣美好的味覺饗宴，說服沒有吃素習慣者「沒肉，也能吃得很享受」。他約20年前首度品嚐來自台灣的素肉和素海鮮，至今仍樂在其中。他說，料理得宜的台灣素食既展現台灣飲食文化特色，也符合持續增加的素食人口需求，具可觀國際發展潛力。跨國數據比較網站Finder的資訊顯示，目前英國近14%成人（約720萬人）採取「無肉飲食」，其中6.5%為素食主義者（vegetarians），4.5%吃的是「海鮮素」，純素主義者（vegans）則占約2.5%。有「台菜王子」封號的黃景龍為忠實傳達台灣素食料理特色，特別將重達數十公斤的醬汁和調味料自台灣運來英國。為揣摩吃素者的味覺偏好，他19日抵達英國後，嚴格實施3天「清口」，同時親自選購所有食材，並在22日活動登場前先到曼徹斯特的素食餐館進行田野考察，見證本地年輕世代如何以葡萄酒搭配裹著濃稠糖醋醬汁的油炸素料，吃得津津有味。獲國內外獎項肯定的黃景龍曾數次受台灣官方之邀，前往北美洲、南美洲、澳洲等地推展「美食外交」。此次在英國，他選擇以大量運用本地民眾熟悉的甜椒、番茄、花椰菜為基礎，結合台灣特色醬料和素料，既顧及西式素食講究善用原食材的精神，也展現亞洲調味風格與料理技法。黃景龍告訴中央社，根據他的實務經驗，素食是最容易達成跨界融合，也是最容易在國際間推廣的料理類別，主要原因包括食材的高度共通性和普遍性，例如此次他在糖醋素魚料理加入檸檬葉，除了有助增添味覺層次，也是善用西方美食愛好者十分熟悉的東亞糖醋與南洋香料風味。考量永續飲食是國際潮流，黃景龍提到，既美味又符合永續原則的台灣素食料理可以是推廣台灣的最佳媒介。今天發布的「國防戰略檢討」報告建議澳洲進行第二次世界大戰以來最大規模的國防策略調整，將長程精準打擊，國內生產導引武器及外交列為優先事項。路透社報導，這份報告說，美國不再是「印太地區的單極領導者」，美中之間的激烈競爭正在定義這個地區，而強權競爭「有可能引發衝突」。報告指出，澳洲北部基地將成為嚇阻對手、保護貿易路線和通訊的重點。報告還說，中國正進行自第二次世界大戰以來最大規模的軍事建設，並在澳洲鄰近地區進行戰略競爭。這份機密報告的公開版本說，澳洲必須「避免我們作為一個國家當前面臨的最高等級戰略風險，也就是區域內可能發生重大衝突。」報告說，在這個「飛彈時代」，對澳洲的軍事威脅並不需要入侵。澳洲將與美國更加密切合作，包括增加雙邊軍事計畫以及接受更多美軍輪流進駐，其中包括潛艦。報告同時提到，澳洲還必須加強與太平洋和東南亞國家的往來。澳洲總理艾班尼斯（Anthony Albanese）說，這份報告的結果「將強化我們的國家安全，並確保我們對未來挑戰做好準備。」澳洲國防經費將在今後10年增加，但未來4年將穩定保持在190億澳元（約新台幣 ...

# %% [markdown]
# ### 做分詞

# %%
#分詞
seg_words_list = jieba.lcut(all_article_text)
seg_words_list
# Out:
# ['中國',
#  '駐',
#  '法國',
#  '大使',
#  '盧沙野',
#  '近日',
#  '的',
#  '公開',
#  '發言',
#  '引發',
#  '爭議',
#  '，',
#  '近',
#  '80',
#  '名',
#  '歐洲',
#  '議員',
#  '在',
#  '法國',
#  '「',
#  '世界報',
#  '」',
#  '發表',
#  '公開信',
#  '，',
#  '呼籲',
#  '法國',
#  '外交部長',
#  '柯隆納',
#  '（',
#  'Catherine',
#  ' ',
#  'Colonna',
#  '）',
#  '宣布',
#  '將盧沙',
#  '野列',
#  '為',
#  '不',
#  '受歡迎',
#  '人物',
#  '。',
#  '綜合',
#  '媒體',
#  '報導',
#  '，',
#  '盧沙野',
#  '近日',
#  '接受',
#  '法媒',
#  '訪問',
#  '時指',
#  '「',
#  '前',
#  '蘇聯',
#  '國家',
#  '並無',
#  '主權國',
#  '地位',
#  '」',
#  '、',
#  '「',
#  '克里米亞半島',
#  '是',
#  '俄羅斯',
#  '的',
#  '一部分',
#  '」',
#  '，',
#  '相關',
#  '言論',
#  '不但',
#  '惹怒',
#  '烏克蘭',
#  '及',
#  '波羅的海',
#  '三國',
#  '，',
#  '也',
#  '引發',
#  '歐盟',
#  '與',
#  '法國',
#  '政界',
#  '的',
#  '不滿',
#  '。',
#  '近',
#  '80',
#  '名',
#  '歐洲',
#  '議員',
#  '23',
#  '日',
#  '在',
#  '法國',
#  '世界報',
#  '（',
#  'Le',
#  ' ',
#  'Monde',
#  '）',
#  '發表',
#  '公開信',
#  '表示',
#  '，',
#  '盧沙野',
#  '的',
#  '激進',
#  '言論',
#  '嚴重',
#  '侮辱',
#  '相關',
#  '國家',
#  '的',
#  '歷史',
#  '、',
#  '文化',
#  '及',
#  '完整性',
#  '，',
#  '並且',
#  '明顯',
#  '違反',
#  '國際法',
#  '，',
#  '必須',
#  '視為',
#  '對',
#  '法國',
#  '歐洲',
#  '夥伴',
#  '國家',
#  '安全',
#  '的',
#  '威脅',
#  '。',
#  '公開信',
#  '強調',
#  '，',
#  '「',
#  '不管',
#  '是',
#  '中國',
#  '，',
#  '或',
#  '任何',
#  '其他',
#  '國家',
#  '，',
#  '無權',
#  '質疑',
#  '他國',
#  '的',
#  '主權',
#  '。',
#  '主權',
#  '不是',
#  '一個',
#  '外交',
#  '玩具',
#  '，',
#  '而是',
#  '國際',
#  '關係',
#  '、',
#  '國際法',
#  '和',
#  '『',
#  '聯合國',
#  '憲章',
#  '』',
#  '的',
#  '基本要素',
#  '」',
#  '。',
#  '這封',
#  '公開信',
#  '中',
#  '形容',
#  '，',
#  '盧沙野',
#  '的',
#  '言論',
#  '是',
#  '最',
#  '糟糕',
#  '的',
#  '「',
#  '戰狼',
#  '」',
#  '行徑',
#  '，',
#  '完全',
#  '超出',
#  '外交辭令',
#  '可',
#  '接受',
#  '的',
#  '範疇',
#  '。',
#  '特別是在',
#  '俄羅斯',
#  '侵犯',
#  '烏克蘭',
#  '令',
#  '歐洲',
#  '陷入',
#  '戰火',
#  '之際',
#  '，',
#  '民主',
#  '世界',
#  '必須',
#  '態度',
#  '堅定',
#  '地',
#  '捍衛',
#  '盟友',
#  '主權',
#  '。',
#  '這些',
#  '歐洲',
#  '議員',
#  '呼籲',
#  '柯隆納將',
#  '盧沙野列',
#  '為',
#  '「',
#  '不',
#  '受歡迎',
#  '人物',
#  '」',
#  '。',
#  '盧沙野',
#  '21',
#  '日',
#  '接受',
#  '法國',
#  'LCI',
#  '新聞',
#  '台',
#  '訪問',
#  '，',
#  '主持人',
#  '問說',
#  '「',
#  '克里米亞',
#  '是否',
#  '屬於',
#  '烏克蘭',
#  '」',
#  '，',
#  '盧沙野',
#  '回答',
#  '，',
#  '「',
#  '不',
#  '一定',
#  '，',
#  '取決',
#  '我們',
#  '如何',
#  '看待',
#  '這些',
#  '問題',
#  '…',
#  '沒有',
#  '這麼',
#  '簡單',
#  '」',
#  '。',
#  '主持人',
#  '提醒',
#  '，',
#  '根據',
#  '國際法',
#  '，',
#  '克里米亞',
#  '屬於',
#  '烏克蘭',
#  '。',
#  '盧沙野',
#  '卻說',
#  '，',
#  '「',
#  '根據',
#  '國際法',
#  '，',
#  '這些',
#  '前',
#  '蘇聯',
#  '國家',
#  '沒有',
#  '有效',
#  '地位',
#  '，',
#  '因為',
#  '沒有',
#  '國際',
#  '協議',
#  '以',
#  '具體化',
#  '他們',
#  '的',
#  '主權國家',
#  '地位',
#  '」',
#  '。',
#  '包括',
#  '烏克蘭',
#  '在內',
#  '的',
#  '多個',
#  '歐洲',
#  '國家',
#  '批評',
#  '盧沙野',
#  '言論',
#  '荒謬',
#  '，',
#  '要求',
#  '中方',
#  '澄清',
#  '。',
#  '各界',
#  '預期',
#  '可能',
#  '參選',
#  '美國',
#  '總統',
#  '的',
#  '佛羅里達',
#  '州長',
#  '迪尚特',
#  '（',
#  'Ron',
#  ' ',
#  'DeSantis',
#  '）',
#  '今天',
#  '在',
#  '東京',
#  '展開',
#  '國際',
#  '訪問',
#  '行程',
#  '時',
#  '，',
#  '盛讚',
#  '日本',
#  '強化',
#  '國防',
#  '之',
#  '舉',
#  '。',
#  '法新社',
#  '報導',
#  '，',
#  '外界',
#  '普遍',
#  '預期',
#  '共和',
#  '黨籍',
#  '的',
#  '迪尚特',
#  '明年',
#  '將',
#  '尋求',
#  '黨內',
#  '總統',
#  '候選人',
#  '提名',
#  '，',
#  '而',
#  '他',
#  '此次',
#  '訪問',
#  '日本',
#  '、',
#  '韓國',
#  '、',
#  '以色列',
#  '與',
#  '英國',
#  '，',
#  '一般',
#  '認為',
#  '是',
#  '替',
#  '自己',
#  '的',
#  '外交',
#  '和',
#  '安全',
#  '資歷',
#  '增色',
#  '。',
#  '迪尚特',
#  '今天',
#  '在',
#  '正式',
#  '會談',
#  '前',
#  '告訴',
#  '日本首相',
#  '岸田文雄',
#  '，',
#  '「',
#  '我們',
#  '非常',
#  '稱許',
#  '您',
#  '強化',
#  '國防',
#  '的',
#  '努力',
#  '」',
#  '。',
#  '迪尚',
#  '特指',
#  '的',
#  '是',
#  '日本',
#  '當局',
#  '改革',
#  '安全策略',
#  '和',
#  '提高',
#  '國防',
#  '支出',
#  '的',
#  '決定',
#  '。',
#  '按照',
#  '官方',
#  '說法',
#  '，',
#  '迪尚特',
#  '此次',
#  '出訪',
#  '，',
#  '是',
#  '替',
#  '佛州',
#  '創造',
#  '商業機會',
#  '，',
#  '迪尚特',
#  '今天',
#  '也',
#  '不',
#  '忘',
#  '吹捧',
#  '佛州',
#  '的',
#  '經濟',
#  '吸引力',
#  '。',
#  '他',
#  '告訴',
#  '岸田',
#  '：',
#  '「',
#  '我們',
#  '注意',
#  '到',
#  '，',
#  '我們',
#  '是',
#  '沒有',
#  '直飛',
#  '日本',
#  '航班',
#  '的',
#  '全美',
#  '最大',
#  '市場',
#  '。',
#  '」',
#  '他',
#  '說',
#  '，',
#  '希望',
#  '與',
#  '航空公司',
#  '會面',
#  '，',
#  '「',
#  '嘗試',
#  '為此',
#  '做點',
#  '什麼',
#  '」',
#  '。',
#  '日本',
#  '在',
#  '國防',
#  '上',
#  '依賴',
#  '華盛頓',
#  '，',
#  '其',
#  '領導人',
#  '將',
#  '密切',
#  '關注',
#  '明年',
#  '的',
#  '美國',
#  '總統大選',
#  '，',
#  '無論誰',
#  '入主',
#  '白宮',
#  '，',
#  '日本',
#  '都',
#  '渴望',
#  '確保',
#  '兩國邦誼',
#  '穩固',
#  '。',
#  '岸田',
#  '告訴',
#  '迪尚特',
#  '，',
#  '希望',
#  '這次',
#  '訪問',
#  '，',
#  '能',
#  '讓',
#  '迪尚特',
#  '「',
#  '更加',
#  '了解',
#  '日本',
#  '政治',
#  '、',
#  '經濟',
#  '和',
#  '文化',
#  '」',
#  '。',
#  '日本',
#  '上',
#  '月',
#  '於',
#  '佛州',
#  '在',
#  '民族英雄',
#  '大谷',
#  '翔平',
#  '帶領',
#  '下',
#  '抱',
#  '回',
#  '世界',
#  '棒球',
#  '經典',
#  '賽',
#  '冠軍',
#  '，',
#  '迪尚特',
#  '也',
#  '向',
#  '岸田',
#  '道賀',
#  '。',
#  '迪尚',
#  '特說',
#  '：',
#  '「',
#  '真',
#  '希望',
#  '我們',
#  '有',
#  '大谷',
#  '，',
#  '但',
#  '那',
#  '也',
#  '是',
#  '沒',
#  '辦法',
#  '的',
#  '事',
#  '。',
#  '」',
#  '迪尚特',
#  '今晚',
#  '將與',
#  '日本',
#  '外務大臣',
#  '林芳',
#  '正共',
#  '進晚餐',
#  '，',
#  '之後',
#  '啟程',
#  '飛往',
#  '韓國',
#  '首爾',
#  '。',
#  '鐵礦砂',
#  '期貨價格',
#  '跌至',
#  '去年',
#  '12',
#  '月初',
#  '以來',
#  '最低',
#  '水準',
#  '，',
#  '因',
#  '需求',
#  '持續',
#  '疲軟',
#  '繼續',
#  '拖累',
#  '整體',
#  '市場',
#  '情緒',
#  '。',
#  '新加坡',
#  '鐵礦砂',
#  '期貨',
#  '24',
#  '日',
#  '盤中',
#  '重挫',
#  '4.7%',
#  '，',
#  '報',
#  '每噸',
#  '103',
#  '美元',
#  '，',
#  '從',
#  '上周五',
#  '（',
#  '14',
#  '日',
#  '）',
#  '迄今',
#  '重挫',
#  '超過',
#  '11%',
#  '。',
#  '儘管',
#  '中國',
#  '大陸',
#  '正',
#  '處於',
#  '建築業',
#  '傳統',
#  '旺季',
#  '，',
#  '但',
#  '鋼鐵',
#  '消費',
#  '並未',
#  '大幅提高',
#  '，',
#  '這',
#  '使得',
#  '投資人',
#  '重新',
#  '評估',
#  '鐵礦砂',
#  '市場',
#  '的',
#  '復甦',
#  '時程',
#  '。',
#  '大陸',
#  '華泰',
#  '期貨',
#  '表示',
#  '，',
#  '雖然',
#  '鋼廠',
#  '本周',
#  '可能',
#  '會',
#  '在',
#  '五一',
#  '黃金',
#  '周',
#  '假期',
#  '前',
#  '補充',
#  '原',
#  '物料',
#  '，',
#  '但',
#  '除此之外',
#  '的',
#  '需求',
#  '看起來',
#  '較',
#  '為',
#  '溫和',
#  '，',
#  '這將',
#  '限制',
#  '鋼廠',
#  '的',
#  '獲利',
#  '能力',
#  '，',
#  '而且',
#  '可能',
#  '導致',
#  '減產',
#  '。',
#  '在',
#  '供應',
#  '面',
#  '方面',
#  '，',
#  '全球',
#  '第四',
#  '大',
#  '鐵礦砂',
#  '生產商',
#  'Fortescue',
#  '金屬',
#  '集團',
#  '在',
#  '今年',
#  '第',
#  '1',
#  '季',
#  '產量',
#  '持平',
#  '，',
#  '但',
#  '旗下',
#  '新',
#  '的',
#  '鐵礦砂',
#  '生產',
#  '項目',
#  'Iron',
#  ' ',
#  'Bridge',
#  ' ',
#  'Magnetite',
#  '已',
#  '投產',
#  '，',
#  '在',
#  '需求',
#  '沒有',
#  '跟上',
#  '的',
#  '情況',
#  '下',
#  '，',
#  '又',
#  '有',
#  '新',
#  '的',
#  '供應量',
#  '增加',
#  '。',
#  '大連',
#  '鐵礦砂',
#  '期貨',
#  '24',
#  '日',
#  '盤中',
#  '重挫',
#  '3.5%',
#  '至',
#  '每噸',
#  '人民幣',
#  '718.5',
#  '元',
#  '。',
#  '上海',
#  '螺紋鋼',
#  '和',
#  '熱軋卷',
#  '板',
#  '期貨',
#  '都',
#  '下跌',
#  '超過',
#  '2%',
#  '，',
#  '在',
#  '五個',
#  '月',
#  '低點',
#  '附近',
#  '波動',
#  '。',
#  '由於',
#  '市場',
#  '擔心',
#  '中國',
#  '大陸',
#  '經濟',
#  '的',
#  '復甦',
#  '步伐',
#  '，',
#  '基礎',
#  '金屬',
#  '價格',
#  '也',
#  '承受',
#  '壓力',
#  '。',
#  '倫敦',
#  '金屬',
#  '交易所',
#  '銅',
#  '、',
#  '鋁',
#  '、',
#  '鋅',
#  '、',
#  '鎳價均',
#  '走弱',
#  '。',
#  '警方',
#  '表示',
#  '，',
#  '德州',
#  '賈斯坡',
#  '（',
#  'Jasper',
#  '）',
#  '鎮',
#  '今晨',
#  '發生',
#  '槍擊',
#  '，',
#  '9',
#  '名',
#  '參加',
#  '畢業',
#  '舞會',
#  '後續',
#  '攤派',
#  '對',
#  '的',
#  '青少年',
#  '受傷',
#  '。',
#  '警方',
#  '本週',
#  '將在',
#  '小鎮',
#  '的',
#  '中學',
#  '加派',
#  '警力',
#  '維安',
#  '。',
#  '路透社',
#  '報導',
#  '，',
#  '賈斯坡鎮',
#  '位於',
#  '休斯頓',
#  '（',
#  'Houston',
#  '）',
#  '東北',
#  '約',
#  '215',
#  '公里',
#  '，',
#  '居民',
#  '約',
#  '7200',
#  '人',
#  '。',
#  '事發',
#  '地點',
#  '在',
#  '鎮上',
#  '的',
#  '一處',
#  '民宅',
#  '。',
#  '賈斯坡',
#  '郡',
#  '警局',
#  '指出',
#  '，',
#  '傷者',
#  '均',
#  '無',
#  '生命危險',
#  '，',
#  '分別',
#  '送往',
#  '兩家',
#  '醫院',
#  '，',
#  '但',
#  '沒',
#  '說',
#  '槍手',
#  '有',
#  '幾人',
#  '等',
#  '細節',
#  '；',
#  '警方',
#  '聲明',
#  '稱',
#  '「',
#  '全案',
#  '正在',
#  '調查',
#  '，',
#  '已',
#  '帶回',
#  '關係人',
#  '偵訊',
#  '」',
#  '。',
#  '當地',
#  'KBMT',
#  '-',
#  'KJAC',
#  '電視',
#  '新聞報導',
#  '，',
#  '傷者',
#  '年齡',
#  '從',
#  '15',
#  '歲',
#  '到',
#  '19',
#  '歲',
#  '不等',
#  '。',
#  '報導',
#  '稱',
#  '賈斯坡',
#  '高中',
#  '22',
#  '日',
#  '晚間',
#  '在',
#  '教堂',
#  '會議廳',
#  '舉行',
#  '畢業',
#  '舞會',
#  '，',
#  '但',
#  '槍擊',
#  '是',
#  '發生',
#  '在',
#  '舞會',
#  '後',
#  '的',
#  '續',
#  '攤派',
#  '對',
#  '。',
#  '一週',
#  '前',
#  '，',
#  '在',
#  '阿拉巴馬州',
#  '達德',
#  '維爾',
#  '（',
#  'Dadeville',
#  '）',
#  '小鎮',
#  '一場',
#  '「',
#  '甜蜜',
#  '16',
#  '歲',
#  '」',
#  '慶生',
#  '派對',
#  '中',
#  '也',
#  '發生',
#  '槍擊案',
#  '，',
#  '造成',
#  '4',
#  '死',
#  '32',
#  ...]

# %%
# !ls jieba_data
# Out:
# dict.txt.big  dict.txt.small  mydict.txt  stop_words.txt

# %% [markdown]
# ### 準備 stop word

# %%
#stop word
with open(file='jieba_data/stop_words.txt', mode='r', encoding='utf-8') as file:
    stop_words = file.read().split('\n')
stop_words
# Out:
# ['the',
#  'of',
#  'is',
#  'and',
#  'to',
#  'in',
#  'that',
#  'we',
#  'for',
#  'an',
#  'are',
#  'by',
#  'be',
#  'as',
#  'on',
#  'with',
#  'can',
#  'if',
#  'from',
#  'which',
#  'you',
#  'it',
#  'this',
#  'then',
#  'at',
#  'have',
#  'all',
#  'not',
#  'one',
#  'has',
#  'or',
#  'that',
#  '的',
#  '了',
#  '和',
#  '是',
#  '就',
#  '都',
#  '而',
#  '及',
#  '與',
#  '著',
#  '或',
#  '一個',
#  '沒有',
#  '我們',
#  '你們',
#  '妳們',
#  '他們',
#  '她們',
#  '是否',
#  '(',
#  ')',
#  '[',
#  ']',
#  '《',
#  '》',
#  '；',
#  '『',
#  '』',
#  '：',
#  ' ',
#  '’',
#  '（',
#  '）',
#  '、',
#  '」',
#  '「',
#  '。',
#  '，',
#  '在',
#  '他',
#  '日',
#  '對',
#  '但',
#  '也',
#  '有',
#  '上',
#  '年',
#  '時',
#  '後',
#  '說',
#  '月',
#  '為',
#  '表示',
#  '可能',
#  '不',
#  '包括',
#  '顯示',
#  '將',
#  '以',
#  '從',
#  '約',
#  '人',
#  '已',
#  '等',
#  '會',
#  '前',
#  '並',
#  '中',
#  '報導',
#  '國際',
#  '國家',
#  '歲',
#  '報告',
#  '今天',
#  '接受',
#  '以及',
#  '4',
#  '這些',
#  '1',
#  '多',
#  '問題',
#  '可',
#  '第',
#  '5',
#  '其中',
#  '這份',
#  '目前',
#  '至',
#  '19',
#  '到',
#  '讓',
#  '，',
#  '最',
#  '3',
#  '10',
#  '於',
#  '新',
#  '2',
#  '被',
#  ',',
#  '更',
#  '員工',
#  '研究',
#  '活動',
#  '工作',
#  '指出',
#  '人員',
#  '需求',
#  '根據',
#  '情況',
#  '支持',
#  '市場',
#  '增加',
#  '官方',
#  '告訴',
#  '公司',
#  '地區',
#  '料理',
#  '歐洲',
#  '民眾',
#  '公布',
#  '總統',
#  '去年',
#  '死亡',
#  '期間',
#  '提名',
#  '開始',
#  '媒體',
#  '進行',
#  '發生',
#  '參加',
#  '料理',
#  'Model',
#  '以來',
#  '警方',
#  '因為',
#  '台',
#  '沒',
#  '這樣',
#  '曾',
#  '因',
#  '素',
#  '能',
#  '生產',
#  '近',
#  '希望',
#  '這',
#  '導致',
#  '訪問',
#  '後果',
#  '主要',
#  '這個',
#  '雇主',
#  '安全',
#  '我',
#  '大',
#  '下',
#  '超過',
#  '龍',
#  '未',
#  '省長',
#  '政策',
#  '舉行',
#  '計畫',
#  '特色',
#  '文化',
#  '稱',
#  '世界',
#  '所',
#  '季',
#  '羅',
#  '-',
#  '就是',
#  '2019',
#  '未來',
#  '屬於',
#  '確保',
#  '地',
#  '自己',
#  'Y',
#  '出現',
#  '嚴重',
#  '雙方',
#  '引發',
#  '必須',
#  '仍',
#  '名',
#  '又',
#  '此次',
#  '吃',
#  '之間',
#  '當局',
#  '明年',
#  '言論',
#  '12',
#  '22',
#  '向',
#  '同時',
#  '調查',
#  '參與',
#  '持續',
#  '之一',
#  '過早',
#  '議員',
#  '本地',
#  '由',
#  '糖醋',
#  '點',
#  '億',
#  '過去',
#  '這是',
#  '這類',
#  '人士',
#  '獲得',
#  '近日',
#  '發表',
#  '呼籲',
#  '地位',
#  '相關',
#  '其他',
#  '如何',
#  '這麼',
#  '除了',
#  '發布',
#  '環境',
#  '24',
#  '政黨',
#  '21',
#  '在內',
#  '批評',
#  '賽',
#  '預期',
#  '強化',
#  '認為',
#  '關注',
#  '政治',
#  '儘管',
#  '雖然',
#  '今年',
#  '9',
#  '將在',
#  '正在',
#  '最佳',
#  '18',
#  '很',
#  '容易',
#  '灣',
#  '只',
#  '做',
#  '至少',
#  '具',
#  '取得',
#  '20',
#  '者',
#  '既',
#  '獲',
#  '可以',
#  '符合',
#  '旗下',
#  '飲食',
#  '自',
#  '內',
#  '反',
#  '2020',
#  '2023',
#  '完成',
#  '分析',
#  '000',
#  '像',
#  '挑戰',
#  '行為',
#  '流出',
#  '電視',
#  '機車',
#  '網站',
#  '吃素',
#  '廚師',
#  '美食',
#  '味覺',
#  '客戶',
#  '好',
#  '2021',
#  '通常',
#  '大陸',
#  '一份',
#  '萬',
#  '內容',
#  '指控',
#  '兩度',
#  '擔任',
#  '人們']

# %% [markdown]
# ### 準備一個利用stop word過濾後的分詞結果

# %%
#分詞
seg_stop_words_list = []
seg_words_list = jieba.lcut(all_article_text)
for term in seg_words_list:
    if term not in stop_words:
        seg_stop_words_list.append(term)
seg_stop_words_list
# Out:
# ['中國',
#  '駐',
#  '法國',
#  '大使',
#  '盧沙野',
#  '公開',
#  '發言',
#  '爭議',
#  '80',
#  '法國',
#  '世界報',
#  '公開信',
#  '法國',
#  '外交部長',
#  '柯隆納',
#  'Catherine',
#  'Colonna',
#  '宣布',
#  '將盧沙',
#  '野列',
#  '受歡迎',
#  '人物',
#  '綜合',
#  '盧沙野',
#  '法媒',
#  '時指',
#  '蘇聯',
#  '並無',
#  '主權國',
#  '克里米亞半島',
#  '俄羅斯',
#  '一部分',
#  '不但',
#  '惹怒',
#  '烏克蘭',
#  '波羅的海',
#  '三國',
#  '歐盟',
#  '法國',
#  '政界',
#  '不滿',
#  '80',
#  '23',
#  '法國',
#  '世界報',
#  'Le',
#  'Monde',
#  '公開信',
#  '盧沙野',
#  '激進',
#  '侮辱',
#  '歷史',
#  '完整性',
#  '並且',
#  '明顯',
#  '違反',
#  '國際法',
#  '視為',
#  '法國',
#  '夥伴',
#  '威脅',
#  '公開信',
#  '強調',
#  '不管',
#  '中國',
#  '任何',
#  '無權',
#  '質疑',
#  '他國',
#  '主權',
#  '主權',
#  '不是',
#  '外交',
#  '玩具',
#  '而是',
#  '關係',
#  '國際法',
#  '聯合國',
#  '憲章',
#  '基本要素',
#  '這封',
#  '公開信',
#  '形容',
#  '盧沙野',
#  '糟糕',
#  '戰狼',
#  '行徑',
#  '完全',
#  '超出',
#  '外交辭令',
#  '範疇',
#  '特別是在',
#  '俄羅斯',
#  '侵犯',
#  '烏克蘭',
#  '令',
#  '陷入',
#  '戰火',
#  '之際',
#  '民主',
#  '態度',
#  '堅定',
#  '捍衛',
#  '盟友',
#  '主權',
#  '柯隆納將',
#  '盧沙野列',
#  '受歡迎',
#  '人物',
#  '盧沙野',
#  '法國',
#  'LCI',
#  '新聞',
#  '主持人',
#  '問說',
#  '克里米亞',
#  '烏克蘭',
#  '盧沙野',
#  '回答',
#  '一定',
#  '取決',
#  '看待',
#  '…',
#  '簡單',
#  '主持人',
#  '提醒',
#  '國際法',
#  '克里米亞',
#  '烏克蘭',
#  '盧沙野',
#  '卻說',
#  '國際法',
#  '蘇聯',
#  '有效',
#  '協議',
#  '具體化',
#  '主權國家',
#  '烏克蘭',
#  '多個',
#  '盧沙野',
#  '荒謬',
#  '要求',
#  '中方',
#  '澄清',
#  '各界',
#  '參選',
#  '美國',
#  '佛羅里達',
#  '州長',
#  '迪尚特',
#  'Ron',
#  'DeSantis',
#  '東京',
#  '展開',
#  '行程',
#  '盛讚',
#  '日本',
#  '國防',
#  '之',
#  '舉',
#  '法新社',
#  '外界',
#  '普遍',
#  '共和',
#  '黨籍',
#  '迪尚特',
#  '尋求',
#  '黨內',
#  '候選人',
#  '日本',
#  '韓國',
#  '以色列',
#  '英國',
#  '一般',
#  '替',
#  '外交',
#  '資歷',
#  '增色',
#  '迪尚特',
#  '正式',
#  '會談',
#  '日本首相',
#  '岸田文雄',
#  '非常',
#  '稱許',
#  '您',
#  '國防',
#  '努力',
#  '迪尚',
#  '特指',
#  '日本',
#  '改革',
#  '安全策略',
#  '提高',
#  '國防',
#  '支出',
#  '決定',
#  '按照',
#  '說法',
#  '迪尚特',
#  '出訪',
#  '替',
#  '佛州',
#  '創造',
#  '商業機會',
#  '迪尚特',
#  '忘',
#  '吹捧',
#  '佛州',
#  '經濟',
#  '吸引力',
#  '岸田',
#  '注意',
#  '直飛',
#  '日本',
#  '航班',
#  '全美',
#  '最大',
#  '航空公司',
#  '會面',
#  '嘗試',
#  '為此',
#  '做點',
#  '什麼',
#  '日本',
#  '國防',
#  '依賴',
#  '華盛頓',
#  '其',
#  '領導人',
#  '密切',
#  '美國',
#  '總統大選',
#  '無論誰',
#  '入主',
#  '白宮',
#  '日本',
#  '渴望',
#  '兩國邦誼',
#  '穩固',
#  '岸田',
#  '迪尚特',
#  '這次',
#  '迪尚特',
#  '更加',
#  '了解',
#  '日本',
#  '經濟',
#  '日本',
#  '佛州',
#  '民族英雄',
#  '大谷',
#  '翔平',
#  '帶領',
#  '抱',
#  '回',
#  '棒球',
#  '經典',
#  '冠軍',
#  '迪尚特',
#  '岸田',
#  '道賀',
#  '迪尚',
#  '特說',
#  '真',
#  '大谷',
#  '那',
#  '辦法',
#  '事',
#  '迪尚特',
#  '今晚',
#  '將與',
#  '日本',
#  '外務大臣',
#  '林芳',
#  '正共',
#  '進晚餐',
#  '之後',
#  '啟程',
#  '飛往',
#  '韓國',
#  '首爾',
#  '鐵礦砂',
#  '期貨價格',
#  '跌至',
#  '月初',
#  '最低',
#  '水準',
#  '疲軟',
#  '繼續',
#  '拖累',
#  '整體',
#  '情緒',
#  '新加坡',
#  '鐵礦砂',
#  '期貨',
#  '盤中',
#  '重挫',
#  '4.7%',
#  '報',
#  '每噸',
#  '103',
#  '美元',
#  '上周五',
#  '14',
#  '迄今',
#  '重挫',
#  '11%',
#  '中國',
#  '正',
#  '處於',
#  '建築業',
#  '傳統',
#  '旺季',
#  '鋼鐵',
#  '消費',
#  '並未',
#  '大幅提高',
#  '使得',
#  '投資人',
#  '重新',
#  '評估',
#  '鐵礦砂',
#  '復甦',
#  '時程',
#  '華泰',
#  '期貨',
#  '鋼廠',
#  '本周',
#  '五一',
#  '黃金',
#  '周',
#  '假期',
#  '補充',
#  '原',
#  '物料',
#  '除此之外',
#  '看起來',
#  '較',
#  '溫和',
#  '這將',
#  '限制',
#  '鋼廠',
#  '獲利',
#  '能力',
#  '而且',
#  '減產',
#  '供應',
#  '面',
#  '方面',
#  '全球',
#  '第四',
#  '鐵礦砂',
#  '生產商',
#  'Fortescue',
#  '金屬',
#  '集團',
#  '產量',
#  '持平',
#  '鐵礦砂',
#  '項目',
#  'Iron',
#  'Bridge',
#  'Magnetite',
#  '投產',
#  '跟上',
#  '供應量',
#  '大連',
#  '鐵礦砂',
#  '期貨',
#  '盤中',
#  '重挫',
#  '3.5%',
#  '每噸',
#  '人民幣',
#  '718.5',
#  '元',
#  '上海',
#  '螺紋鋼',
#  '熱軋卷',
#  '板',
#  '期貨',
#  '下跌',
#  '2%',
#  '五個',
#  '低點',
#  '附近',
#  '波動',
#  '由於',
#  '擔心',
#  '中國',
#  '經濟',
#  '復甦',
#  '步伐',
#  '基礎',
#  '金屬',
#  '價格',
#  '承受',
#  '壓力',
#  '倫敦',
#  '金屬',
#  '交易所',
#  '銅',
#  '鋁',
#  '鋅',
#  '鎳價均',
#  '走弱',
#  '德州',
#  '賈斯坡',
#  'Jasper',
#  '鎮',
#  '今晨',
#  '槍擊',
#  '畢業',
#  '舞會',
#  '後續',
#  '攤派',
#  '青少年',
#  '受傷',
#  '本週',
#  '小鎮',
#  '中學',
#  '加派',
#  '警力',
#  '維安',
#  '路透社',
#  '賈斯坡鎮',
#  '位於',
#  '休斯頓',
#  'Houston',
#  '東北',
#  '215',
#  '公里',
#  '居民',
#  '7200',
#  '事發',
#  '地點',
#  '鎮上',
#  '一處',
#  '民宅',
#  '賈斯坡',
#  '郡',
#  '警局',
#  '傷者',
#  '均',
#  '無',
#  '生命危險',
#  '分別',
#  '送往',
#  '兩家',
#  '醫院',
#  '槍手',
#  '幾人',
#  '細節',
#  '聲明',
#  '全案',
#  '帶回',
#  '關係人',
#  '偵訊',
#  '當地',
#  'KBMT',
#  'KJAC',
#  '新聞報導',
#  '傷者',
#  '年齡',
#  '15',
#  '不等',
#  '賈斯坡',
#  '高中',
#  '晚間',
#  '教堂',
#  '會議廳',
#  '畢業',
#  '舞會',
#  '槍擊',
#  '舞會',
#  '續',
#  '攤派',
#  '一週',
#  '阿拉巴馬州',
#  '達德',
#  '維爾',
#  'Dadeville',
#  '小鎮',
#  '一場',
#  '甜蜜',
#  '16',
#  '慶生',
#  '派對',
#  '槍擊案',
#  '造成',
#  '死',
#  '32',
#  '傷',
#  '名犯',
#  '嫌',
#  '被控',
#  '殺人罪',
#  '美國',
#  '疾病',
#  '管制',
#  '暨',
#  '預防',
#  '中心',
#  'CDC',
#  '槍支',
#  '已成',
#  '美國',
#  '兒少',
#  '致死',
#  '原因',
#  '肇事',
#  '美國廣播公司',
#  '新聞網',
#  'ABC',
#  'News',
#  '賈斯坡鎮',
#  '稍晚',
#  '傳出',
#  '起',
#  '槍擊',
#  '不排',
#  '兩起',
#  '槍擊案',
#  '關聯',
#  '台菜',
#  '名廚',
#  '黃景',
#  '英國',
#  '演繹',
#  '台灣',
#  '素食',
#  '功力',
#  '專業',
#  '讚賞',
#  '策劃',
#  '僑委會',
#  '青年',
#  '親善大使',
#  '謝優康',
#  '超越',
#  '語言',
#  '藩籬',
#  '貼近',
#  '人心',
#  '連結',
#  '英',
#  '橋梁',
#  '僑務',
#  '委員會',
#  '首次',
#  '選拔',
#  '青年',
#  '親善大使',
#  '英國',
#  '出生',
#  '成長',
#  '父母',
#  '來自',
#  '台灣',
#  '謝',
#  '優康',
#  'Oliver',
#  'Hsieh',
#  '全球',
#  '位',
#  '獲選',
#  '青年',
#  '英國',
#  '杜倫',
#  '大學',
#  'Durham',
#  'University',
#  '工程學',
#  '碩士生',
#  '中央社',
#  '採訪',
#  '時說',
#  '台灣',
#  '素食',
#  '英國',
#  '西方',
#  '近期',
#  '潮流',
#  '因此',
#  '嘗試',
#  '透過',
#  '素食',
#  '英國',
#  '推銷',
#  '台灣',
#  '特別',
#  '成長',
#  '背景',
#  '相對',
#  '換位',
#  '思考',
#  '理解',
#  '台英',
#  '觀點',
#  '思維',
#  '情感',
#  '有助',
#  '搭建',
#  '英',
#  '交流',
#  '橋梁',
#  '英國',
#  '視角',
#  '看台',
#  '要',
#  '有效',
#  '宣傳',
#  '不能',
#  '台灣',
#  '角度',
#  '看台',
#  '謝優康',
#  '舉辦',
#  '結合',
#  '英式',
#  '下午茶',
#  '台灣',
#  '茶點',
#  '親善',
#  '地球日',
#  '曼徹斯特',
#  '舉辦',
#  '台灣',
#  '素食',
#  '體驗',
#  '邀請',
#  '黃景',
#  '掌廚',
#  '推出',
#  '道',
#  '組成',
#  '自助餐',
#  '另附',
#  '鳳梨',
#  '酥',
#  '珍珠奶茶',
#  '代表性',
#  '甜點',
#  '黃景',
#  '現場',
#  '簡單',
#  '示範',
#  '幾道',
#  '餐點',
#  '步驟',
#  '入場券',
#  '英鎊',
#  '台幣',
#  '457',
#  '元',
#  '起跳',
#  '菜單',
#  '涵蓋',
#  '漢堡',
#  '肉',
#  '小農',
#  '梅干菜',
#  '割包',
#  '鴨',
#  '割包',
#  '羊肉',
#  '蔬菜湯',
#  '植物',
#  '肉燥',
#  '炒',
#  '米粉',
#  '五柳',
#  '甜椒',
#  '紫菜',
#  '素魚',
#  '鳳梨',
#  '炸素',
#  '魚條',
#  '素鵝',
#  '羅漢',
#  '涼泮素',
#  '鴨絲',
#  '香素',
#  '春卷',
#  '叉燒',
#  '麻油',
#  '米糕',
#  '等現',
#  '部分',
#  '票券',
#  '收益',
#  '捐助',
#  '聯合國',
#  '道',
#  '事務',
#  '協調',
#  '廳',
#  'UNOCHA',
#  '急難',
#  '救助',
#  '協助',
#  '土耳其',
#  '敘利亞',
#  '地震',
#  '災民',
#  '午餐',
#  '晚餐',
#  '兩場',
#  '素食',
#  '體驗',
#  '總計',
#  '300',
#  '亞裔',
#  '社群',
#  '英國',
#  '占',
#  '成',
#  '市議員',
#  '裴柏',
#  'Teresa',
#  'Peppe',
#  '夏沛',
#  'Rob',
#  'Sharpe',
#  '應邀出席',
#  '前來',
#  '一',
#  '嚐',
#  '素食',
#  '義大利',
#  '裔',
#  '專業',
#  '寇',
#  '提塞',
#  'Antonio',
#  'Cortese',
#  '特別喜愛',
#  '再',
#  '脹氣',
#  '植物',
#  '肉燥',
#  '炒',
#  '米粉',
#  '自稱',
#  '一次',
#  '吃掉',
#  '人份',
#  '中央社',
#  '台灣',
#  '素食',
#  '十分',
#  '競爭力',
#  '何時能',
#  '形成',
#  '旋風',
#  '間',
#  '可觀',
#  '商業',
#  '成果',
#  '隨著',
#  '素食',
#  '各國',
#  '接受度',
#  '提升',
#  '期待',
#  '台灣',
#  '素食',
#  '舞台',
#  '擴大',
#  '餐廳',
#  '營運',
#  '經驗',
#  '電視節目',
#  '示範',
#  '希臘',
#  '裔',
#  '艾斯丁',
#  'Solos',
#  'Astin',
#  '中央社',
#  '台灣',
#  '素食',
#  '本事',
#  '提供',
#  '廣大',
#  '愛好者',
#  '含肉',
#  '同樣',
#  '美好',
#  '饗宴',
#  '說服',
#  '習慣',
#  '沒肉',
#  '得',
#  '享受',
#  '年前',
#  '首度',
#  '品嚐',
#  '來自',
#  '台灣',
#  '素肉',
#  '海鮮',
#  '至今',
#  '樂在其中',
#  '得宜',
#  '台灣',
#  '素食',
#  '展現',
#  '台灣',
#  '飲食文化',
#  '素食',
#  '人口',
#  '可觀',
#  '發展潛力',
#  '跨國',
#  '數據',
#  '比較',
#  'Finder',
#  '資訊',
#  '英國',
#  '14%',
#  '成人',
#  '720',
#  '萬人',
#  '採取',
#  '無肉',
#  '6.5%',
#  '素食主義者',
#  'vegetarians',
#  '4.5%',
#  '海鮮',
#  '純素',
#  '主義者',
#  'vegans',
#  '則占約',
#  '2.5%',
#  '台菜',
#  '王子',
#  '封號',
#  '黃景',
#  '龍為',
#  '忠實',
#  '傳達',
#  '台灣',
#  '素食',
#  '特別',
#  '將重',
#  '達',
#  '數十',
#  '公斤',
#  '醬汁',
#  '調味料',
#  '自台灣',
#  '運來',
#  '英國',
#  '揣摩',
#  '偏好',
#  '抵達',
#  '英國',
#  '嚴格',
#  '實施',
#  '天',
#  '清口',
#  '親自',
#  '選購',
#  '所有',
#  '食材',
#  '並在',
#  '登場',
#  '前先',
#  '曼徹斯特',
#  '素食',
#  '餐館',
#  '田野',
#  '考察',
#  '見證',
#  '年輕',
#  '世代',
#  '葡萄酒',
#  '搭配',
#  '裹',
#  '濃稠',
#  '醬汁',
#  '油炸',
#  '素料',
#  '得',
#  '津津有味',
#  '國內外',
#  '獎項',
#  '肯定',
#  '黃景',
#  '數次',
#  '受台灣',
#  '之邀',
#  '前往',
#  '北美洲',
#  '南美洲',
#  '澳洲',
#  '推展',
#  '外交',
#  '英國',
#  '選擇',
#  '大量',
#  '運用',
#  '熟悉',
#  '甜椒',
#  '番茄',
#  '花椰菜',
#  '基礎',
#  '結合',
#  '台灣',
#  '醬料',
#  '素料',
#  '顧及',
#  '西式',
#  '素食',
#  '講究',
#  '善用',
#  '原食材',
#  '精神',
#  '展現',
#  '亞洲',
#  '調味',
#  '風格',
#  '技法',
#  '黃景',
#  '中央社',
#  '實務',
#  '經驗',
#  '素食',
#  '達成',
#  '跨界',
#  '融合',
#  '間',
#  '推廣',
#  '類別',
#  '原因',
#  '食材',
#  '高度',
#  '共通性',
#  '普遍性',
#  '例如',
#  '素魚',
#  '加入',
#  '檸檬',
#  '葉',
#  '有助',
#  '增添',
#  '層次',
#  '善用',
#  '西方',
#  '愛好者',
#  '十分',
#  '熟悉',
#  '東亞',
#  '南洋',
#  '香料',
#  '風味',
#  '考量',
#  '永續',
#  '潮流',
#  '黃景',
#  '提到',
#  '美味',
#  '永續',
#  '原則',
#  '台灣',
#  '素食',
#  '推廣',
#  '台灣',
#  '媒介',
#  '國防',
#  '戰略',
#  '檢討',
#  '建議',
#  '澳洲',
#  '第二次世界大戰',
#  '大規模',
#  '國防',
#  '策略',
#  '調整',
#  '長程',
#  '精準',
#  '打擊',
#  '國內',
#  '導引',
#  '武器',
#  '外交',
#  '列為',
#  '優先',
#  '事項',
#  '路透社',
#  '美國',
#  '不再',
#  '印太',
#  '單極',
#  '領導者',
#  '美',
#  '激烈',
#  ...]

# %% [markdown]
# ### 載入繪圖相關的 library

# %%
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
print(matplotlib.matplotlib_fname())
# Out:
# /opt/conda/lib/python3.10/site-packages/matplotlib/mpl-data/matplotlibrc

# %% [markdown]
# ### 繪製文字雲 ( wordcloud.generate )

# %%
# wordcloud.generate 參數是吃文字內容，以空白為文字區隔
seg_words = ' '.join(seg_words_list)
#seg_words

# %% [markdown]
# ### 繪製文字雲 ( wordcloud.generate_from_frequencies )

# %%
# https://docs.python.org/zh-tw/3/library/collections.html
# 準備一個沒有經過stop word 處理的 counter
from collections import Counter
seg_counter = Counter(seg_words_list)
seg_counter
# Out:
# Counter({'中國': 11,
#          '駐': 1,
#          '法國': 7,
#          '大使': 1,
#          '盧沙野': 8,
#          '近日': 3,
#          '的': 208,
#          '公開': 2,
#          '發言': 1,
#          '引發': 4,
#          '爭議': 1,
#          '，': 393,
#          '近': 5,
#          '80': 2,
#          '名': 4,
#          '歐洲': 24,
#          '議員': 4,
#          '在': 71,
#          '「': 69,
#          '世界報': 2,
#          '」': 69,
#          '發表': 3,
#          '公開信': 4,
#          '呼籲': 3,
#          '外交部長': 1,
#          '柯隆納': 1,
#          '（': 82,
#          'Catherine': 1,
#          ' ': 66,
#          'Colonna': 1,
#          '）': 82,
#          '宣布': 1,
#          '將盧沙': 1,
#          '野列': 1,
#          '為': 18,
#          '不': 11,
#          '受歡迎': 2,
#          '人物': 2,
#          '。': 208,
#          '綜合': 2,
#          '媒體': 6,
#          '報導': 19,
#          '接受': 10,
#          '法媒': 1,
#          '訪問': 5,
#          '時指': 1,
#          '前': 11,
#          '蘇聯': 2,
#          '國家': 19,
#          '並無': 2,
#          '主權國': 1,
#          '地位': 3,
#          '、': 59,
#          '克里米亞半島': 1,
#          '是': 37,
#          '俄羅斯': 3,
#          '一部分': 1,
#          '相關': 3,
#          '言論': 4,
#          '不但': 1,
#          '惹怒': 1,
#          '烏克蘭': 6,
#          '及': 14,
#          '波羅的海': 1,
#          '三國': 1,
#          '也': 28,
#          '歐盟': 3,
#          '與': 22,
#          '政界': 1,
#          '不滿': 2,
#          '23': 2,
#          '日': 14,
#          'Le': 1,
#          'Monde': 1,
#          '表示': 25,
#          '激進': 1,
#          '嚴重': 4,
#          '侮辱': 1,
#          '歷史': 2,
#          '文化': 4,
#          '完整性': 1,
#          '並且': 1,
#          '明顯': 1,
#          '違反': 1,
#          '國際法': 4,
#          '必須': 4,
#          '視為': 1,
#          '對': 16,
#          '夥伴': 1,
#          '安全': 5,
#          '威脅': 6,
#          '強調': 2,
#          '不管': 1,
#          '或': 8,
#          '任何': 2,
#          '其他': 3,
#          '無權': 1,
#          '質疑': 1,
#          '他國': 1,
#          '主權': 3,
#          '不是': 2,
#          '一個': 4,
#          '外交': 4,
#          '玩具': 1,
#          '而是': 1,
#          '國際': 14,
#          '關係': 1,
#          '和': 37,
#          '『': 2,
#          '聯合國': 2,
#          '憲章': 1,
#          '』': 2,
#          '基本要素': 1,
#          '這封': 1,
#          '中': 9,
#          '形容': 1,
#          '最': 7,
#          '糟糕': 1,
#          '戰狼': 1,
#          '行徑': 1,
#          '完全': 1,
#          '超出': 1,
#          '外交辭令': 1,
#          '可': 7,
#          '範疇': 1,
#          '特別是在': 1,
#          '侵犯': 1,
#          '令': 1,
#          '陷入': 1,
#          '戰火': 1,
#          '之際': 2,
#          '民主': 4,
#          '世界': 4,
#          '態度': 2,
#          '堅定': 2,
#          '地': 4,
#          '捍衛': 1,
#          '盟友': 1,
#          '這些': 9,
#          '柯隆納將': 1,
#          '盧沙野列': 1,
#          '21': 3,
#          'LCI': 1,
#          '新聞': 2,
#          '台': 5,
#          '主持人': 2,
#          '問說': 1,
#          '克里米亞': 2,
#          '是否': 3,
#          '屬於': 4,
#          '回答': 2,
#          '一定': 1,
#          '取決': 1,
#          '我們': 11,
#          '如何': 3,
#          '看待': 1,
#          '問題': 8,
#          '…': 1,
#          '沒有': 6,
#          '這麼': 3,
#          '簡單': 2,
#          '提醒': 1,
#          '根據': 8,
#          '卻說': 1,
#          '有效': 2,
#          '因為': 5,
#          '協議': 1,
#          '以': 9,
#          '具體化': 1,
#          '他們': 4,
#          '主權國家': 1,
#          '包括': 13,
#          '在內': 3,
#          '多個': 2,
#          '批評': 3,
#          '荒謬': 1,
#          '要求': 1,
#          '中方': 1,
#          '澄清': 1,
#          '各界': 1,
#          '預期': 3,
#          '可能': 15,
#          '參選': 5,
#          '美國': 18,
#          '總統': 14,
#          '佛羅里達': 1,
#          '州長': 1,
#          '迪尚特': 9,
#          'Ron': 1,
#          'DeSantis': 1,
#          '今天': 15,
#          '東京': 2,
#          '展開': 2,
#          '行程': 1,
#          '時': 6,
#          '盛讚': 1,
#          '日本': 10,
#          '強化': 3,
#          '國防': 7,
#          '之': 2,
#          '舉': 1,
#          '法新社': 5,
#          '外界': 2,
#          '普遍': 1,
#          '共和': 1,
#          '黨籍': 1,
#          '明年': 4,
#          '將': 13,
#          '尋求': 1,
#          '黨內': 1,
#          '候選人': 2,
#          '提名': 6,
#          '而': 10,
#          '他': 35,
#          '此次': 4,
#          '韓國': 2,
#          '以色列': 2,
#          '英國': 13,
#          '一般': 1,
#          '認為': 3,
#          '替': 2,
#          '自己': 4,
#          '資歷': 1,
#          '增色': 1,
#          '正式': 1,
#          '會談': 1,
#          '告訴': 7,
#          '日本首相': 1,
#          '岸田文雄': 1,
#          '非常': 1,
#          '稱許': 1,
#          '您': 1,
#          '努力': 1,
#          '迪尚': 2,
#          '特指': 1,
#          '當局': 4,
#          '改革': 1,
#          '安全策略': 1,
#          '提高': 2,
#          '支出': 1,
#          '決定': 1,
#          '按照': 1,
#          '官方': 5,
#          '說法': 1,
#          '出訪': 1,
#          '佛州': 4,
#          '創造': 1,
#          '商業機會': 1,
#          '忘': 1,
#          '吹捧': 1,
#          '經濟': 3,
#          '吸引力': 1,
#          '岸田': 3,
#          '：': 12,
#          '注意': 1,
#          '到': 8,
#          '直飛': 1,
#          '航班': 1,
#          '全美': 1,
#          '最大': 2,
#          '市場': 7,
#          '說': 15,
#          '希望': 5,
#          '航空公司': 1,
#          '會面': 1,
#          '嘗試': 2,
#          '為此': 1,
#          '做點': 1,
#          '什麼': 1,
#          '上': 11,
#          '依賴': 1,
#          '華盛頓': 1,
#          '其': 2,
#          '領導人': 1,
#          '密切': 1,
#          '關注': 3,
#          '總統大選': 4,
#          '無論誰': 1,
#          '入主': 1,
#          '白宮': 1,
#          '都': 7,
#          '渴望': 1,
#          '確保': 4,
#          '兩國邦誼': 1,
#          '穩固': 1,
#          '這次': 2,
#          '能': 5,
#          '讓': 8,
#          '更加': 2,
#          '了解': 2,
#          '政治': 3,
#          '月': 19,
#          '於': 7,
#          '民族英雄': 1,
#          '大谷': 2,
#          '翔平': 1,
#          '帶領': 1,
#          '下': 4,
#          '抱': 1,
#          '回': 1,
#          '棒球': 1,
#          '經典': 1,
#          '賽': 3,
#          '冠軍': 1,
#          '向': 4,
#          '道賀': 1,
#          '特說': 1,
#          '真': 1,
#          '有': 27,
#          '但': 19,
#          '那': 2,
#          '沒': 5,
#          '辦法': 1,
#          '事': 2,
#          '今晚': 1,
#          '將與': 2,
#          '外務大臣': 1,
#          '林芳': 1,
#          '正共': 1,
#          '進晚餐': 1,
#          '之後': 1,
#          '啟程': 1,
#          '飛往': 1,
#          '首爾': 1,
#          '鐵礦砂': 6,
#          '期貨價格': 1,
#          '跌至': 1,
#          '去年': 5,
#          '12': 3,
#          '月初': 1,
#          '以來': 5,
#          '最低': 1,
#          '水準': 2,
#          '因': 5,
#          '需求': 7,
#          '持續': 4,
#          '疲軟': 1,
#          '繼續': 1,
#          '拖累': 1,
#          '整體': 1,
#          '情緒': 1,
#          '新加坡': 5,
#          '期貨': 4,
#          '24': 3,
#          '盤中': 2,
#          '重挫': 3,
#          '4.7%': 1,
#          '報': 1,
#          '每噸': 2,
#          '103': 1,
#          '美元': 5,
#          '從': 10,
#          '上周五': 2,
#          '14': 1,
#          '迄今': 1,
#          '超過': 5,
#          '11%': 1,
#          '儘管': 3,
#          '大陸': 6,
#          '正': 2,
#          '處於': 1,
#          '建築業': 1,
#          '傳統': 2,
#          '旺季': 1,
#          '鋼鐵': 1,
#          '消費': 1,
#          '並未': 2,
#          '大幅提高': 1,
#          '這': 6,
#          '使得': 1,
#          '投資人': 2,
#          '重新': 1,
#          '評估': 1,
#          '復甦': 2,
#          '時程': 1,
#          '華泰': 1,
#          '雖然': 3,
#          '鋼廠': 2,
#          '本周': 1,
#          '會': 13,
#          '五一': 1,
#          '黃金': 1,
#          '周': 1,
#          '假期': 1,
#          '補充': 1,
#          '原': 1,
#          '物料': 1,
#          '除此之外': 1,
#          '看起來': 1,
#          '較': 2,
#          '溫和': 2,
#          '這將': 2,
#          '限制': 1,
#          '獲利': 2,
#          '能力': 1,
#          '而且': 1,
#          '導致': 5,
#          '減產': 1,
#          '供應': 1,
#          '面': 1,
#          '方面': 1,
#          '全球': 3,
#          '第四': 1,
#          '大': 5,
#          '生產商': 1,
#          'Fortescue': 1,
#          '金屬': 3,
#          '集團': 4,
#          '今年': 3,
#          '第': 8,
#          '1': 9,
#          '季': 5,
#          '產量': 1,
#          '持平': 1,
#          '旗下': 3,
#          '新': 7,
#          '生產': 5,
#          '項目': 2,
#          'Iron': 1,
#          'Bridge': 1,
#          'Magnetite': 1,
#          '已': 11,
#          '投產': 1,
#          '跟上': 1,
#          '情況': 7,
#          '又': 4,
#          '供應量': 1,
#          '增加': 7,
#          '大連': 1,
#          '3.5%': 1,
#          '至': 7,
#          '人民幣': 1,
#          '718.5': 1,
#          '元': 2,
#          '上海': 4,
#          '螺紋鋼': 1,
#          '熱軋卷': 1,
#          '板': 1,
#          '下跌': 1,
#          '2%': 1,
#          '五個': 1,
#          '低點': 1,
#          '附近': 2,
#          '波動': 1,
#          '由於': 1,
#          '擔心': 1,
#          '步伐': 1,
#          '基礎': 2,
#          '價格': 1,
#          '承受': 1,
#          '壓力': 3,
#          '倫敦': 1,
#          '交易所': 1,
#          '銅': 1,
#          '鋁': 1,
#          '鋅': 1,
#          '鎳價均': 1,
#          '走弱': 1,
#          '警方': 8,
#          '德州': 2,
#          '賈斯坡': 3,
#          'Jasper': 1,
#          '鎮': 1,
#          '今晨': 1,
#          '發生': 5,
#          '槍擊': 3,
#          '9': 3,
#          '參加': 5,
#          '畢業': 2,
#          '舞會': 3,
#          '後續': 1,
#          '攤派': 2,
#          '青少年': 2,
#          '受傷': 1,
#          '本週': 1,
#          '將在': 3,
#          '小鎮': 2,
#          '中學': 1,
#          '加派': 1,
#          '警力': 1,
#          '維安': 1,
#          '路透社': 4,
#          '賈斯坡鎮': 2,
#          '位於': 1,
#          '休斯頓': 1,
#          'Houston': 1,
#          '東北': 1,
#          '約': 10,
#          '215': 1,
#          '公里': 2,
#          '居民': 1,
#          '7200': 1,
#          '人': 13,
#          '事發': 1,
#          '地點': 1,
#          '鎮上': 1,
#          '一處': 1,
#          '民宅': 1,
#          '郡': 1,
#          '警局': 2,
#          '指出': 7,
#          '傷者': 2,
#          '均': 1,
#          '無': 2,
#          '生命危險': 1,
#          '分別': 1,
#          '送往': 1,
#          '兩家': 1,
#          '醫院': 1,
#          '槍手': 1,
#          '幾人': 1,
#          '等': 12,
#          '細節': 1,
#          '；': 5,
#          '聲明': 1,
#          '稱': 5,
#          '全案': 1,
#          '正在': 3,
#          '調查': 4,
#          '帶回': 1,
#          '關係人': 1,
#          '偵訊': 1,
#          '當地': 2,
#          'KBMT': 1,
#          '-': 7,
#          'KJAC': 1,
#          '電視': 3,
#          '新聞報導': 1,
#          '年齡': 1,
#          '15': 1,
#          '歲': 15,
#          '19': 7,
#          '不等': 1,
#          '高中': 1,
#          '22': 3,
#          '晚間': 1,
#          '教堂': 1,
#          '會議廳': 1,
#          '舉行': 5,
#          '後': 12,
#          '續': 1,
#          '一週': 1,
#          '阿拉巴馬州': 1,
#          '達德': 1,
#          '維爾': 1,
#          'Dadeville': 1,
#          '一場': 1,
#          '甜蜜': 1,
#          '16': 1,
#          '慶生': 1,
#          '派對': 1,
#          '槍擊案': 2,
#          '造成': 2,
#          '4': 8,
#          '死': 1,
#          '32': 1,
#          '傷': 1,
#          '5': 11,
#          '名犯': 1,
#          '嫌': 1,
#          '被控': 2,
#          '殺人罪': 1,
#          '疾病': 3,
#          '管制': 1,
#          '暨': 1,
#          '預防': 2,
#          '中心': 1,
#          'CDC': 1,
#          '槍支': 1,
#          '已成': 1,
#          '兒少': 1,
#          '致死': 1,
#          '主要': 5,
#          '原因': 2,
#          '機車': 3,
#          '肇事': 1,
#          '美國廣播公司': 1,
#          '新聞網': 2,
#          'ABC': 1,
#          'News': 1,
#          '稍晚': 1,
#          '傳出': 1,
#          '2': 7,
#          '起': 1,
#          '不排': 1,
#          '兩起': 1,
#          '之間': 4,
#          '關聯': 1,
#          '台菜': 2,
#          '名廚': 1,
#          '黃景': 7,
#          '龍': 6,
#          '演繹': 1,
#          '台灣': 19,
#          '素食': 17,
#          '料理': 13,
#          '功力': 1,
#          '本地': 4,
#          '專業': 2,
#          '廚師': 3,
#          '讚賞': 1,
#          '策劃': 1,
#          '活動': 9,
#          '僑委會': 1,
#          '青年': 3,
#          '親善大使': 2,
#          '謝優康': 2,
#          '飲食': 3,
#          '超越': 1,
#          '語言': 1,
#          '藩籬': 1,
#          '貼近': 1,
#          '人心': 1,
#          '連結': 1,
#          '英': 2,
#          '最佳': 3,
#          '橋梁': 2,
#          '之一': 3,
#          '僑務': 1,
#          '委員會': 1,
#          '首次': 2,
#          '選拔': 1,
#          '出生': 2,
#          '成長': 2,
#          '父母': 1,
#          '來自': 2,
#          '謝': 1,
#          '優康': 1,
#          'Oliver': 1,
#          'Hsieh': 1,
#          '18': 3,
#          '位': 1,
#          '獲選': 1,
#          '目前': 8,
#          '杜倫': 1,
#          '大學': 2,
#          'Durham': 1,
#          'University': 2,
#          '工程學': 1,
#          '碩士生': 1,
#          '中央社': 4,
#          '採訪': 1,
#          '時說': 1,
#          '很': 3,
#          '特色': 4,
#          '西方': 2,
#          '近期': 2,
#          '吃素': 3,
#          '潮流': 2,
#          '因此': 2,
#          '透過': 2,
#          '民眾': 9,
#          '推銷': 1,
#          '特別': 2,
#          '背景': 2,
#          '相對': 2,
#          '容易': 3,
#          '換位': 1,
#          '思考': 1,
#          '理解': 1,
#          '台英': 1,
#          '雙方': 4,
#          '觀點': 1,
#          '思維': 1,
#          '情感': 1,
#          '有助': 2,
#          '搭建': 1,
#          '交流': 1,
#          '以及': 8,
#          '視角': 1,
#          '看台': 2,
#          '灣': 3,
#          '要': 1,
#          '宣傳': 1,
#          '就': 8,
#          '不能': 1,
#          '只': 3,
#          '角度': 2,
#          '曾': 6,
#          '舉辦': 2,
#          '結合': 2,
#          '英式': 1,
#          '下午茶': 1,
#          '茶點': 1,
#          '親善': 1,
#          '地球日': 1,
#          '曼徹斯特': 2,
#          '體驗': 2,
#          '邀請': 1,
#          '掌廚': 1,
#          '推出': 1,
#          '由': 4,
#          '10': 5,
#          '道': 2,
#          '組成': 1,
#          '自助餐': 1,
#          '另附': 1,
#          '鳳梨': 2,
#          '酥': 1,
#          '珍珠奶茶': 1,
#          '代表性': 1,
#          '甜點': 1,
#          '現場': 1,
#          '示範': 2,
#          '幾道': 1,
#          '餐點': 1,
#          '步驟': 1,
#          '入場券': 1,
#          '英鎊': 1,
#          '台幣': 4,
#          '457': 1,
#          '起跳': 1,
#          '菜單': 1,
#          '涵蓋': 1,
#          '素': 6,
#          '漢堡': 1,
#          '肉': 1,
#          '小農': 1,
#          '梅干菜': 1,
#          '割包': 2,
#          '鴨': 1,
#          '羊肉': 1,
#          '蔬菜湯': 1,
#          '植物': 2,
#          '肉燥': 2,
#          '炒': 2,
#          '米粉': 2,
#          '五柳': 1,
#          '甜椒': 2,
#          '紫菜': 1,
#          '素魚': 2,
#          '糖醋': 4,
#          '炸素': 1,
#          '魚條': 1,
#          '素鵝': 1,
#          '羅漢': 1,
#          '涼泮素': 1,
#          '鴨絲': 1,
#          '香素': 1,
#          '春卷': 1,
#          '叉燒': 1,
#          '麻油': 1,
#          '米糕': 1,
#          '等現': 1,
#          '做': 3,
#          '網站': 3,
#          '部分': 1,
#          '票券': 1,
#          '收益': 1,
#          '捐助': 1,
#          '事務': 1,
#          '協調': 1,
#          '廳': 1,
#          'UNOCHA': 1,
#          '急難': 1,
#          '救助': 1,
#          '計畫': 4,
#          '協助': 1,
#          '土耳其': 2,
#          '敘利亞': 1,
#          '地震': 4,
#          '災民': 1,
#          '午餐': 1,
#          '晚餐': 1,
#          '兩場': 1,
#          '總計': 1,
#          '300': 1,
#          '其中': 7,
#          '亞裔': 1,
#          '社群': 2,
#          '占': 1,
#          '成': 1,
#          '市議員': 1,
#          '裴柏': 1,
#          'Teresa': 1,
#          'Peppe': 1,
#          '夏沛': 1,
#          'Rob': 1,
#          'Sharpe': 1,
#          '應邀出席': 1,
#          '前來': 1,
#          '一': 2,
#          '嚐': 1,
#          '義大利': 2,
#          '裔': 2,
#          '寇': 1,
#          '提塞': 1,
#          'Antonio': 1,
#          'Cortese': 1,
#          '特別喜愛': 1,
#          '吃': 4,
#          '再': 2,
#          '多': 9,
#          '脹氣': 1,
#          '自稱': 1,
#          '一次': 2,
#          '吃掉': 1,
#          '至少': 3,
#          '人份': 1,
#          '十分': 2,
#          '具': 3,
#          '競爭力': 1,
#          '何時能': 1,
#          '形成': 1,
#          '旋風': 1,
#          '間': 2,
#          '取得': 3,
#          '可觀': 2,
#          '商業': 1,
#          '成果': 1,
#          '隨著': 2,
#          '各國': 1,
#          '接受度': 1,
#          '提升': 1,
#          '期待': 1,
#          '舞台': 1,
#          '擴大': 1,
#          '20': 3,
#          '年': 22,
#          '餐廳': 1,
#          '營運': 1,
#          '經驗': 2,
#          '參與': 4,
#          '電視節目': 1,
#          '希臘': 1,
#          '艾斯丁': 1,
#          'Solos': 1,
#          'Astin': 1,
#          '本事': 1,
#          '提供': 2,
#          '廣大': 1,
#          '美食': 3,
#          '愛好者': 2,
#          '含肉': 1,
#          '同樣': 1,
#          '美好': 1,
#          '味覺': 3,
#          '饗宴': 1,
#          '說服': 1,
#          '習慣': 1,
#          '者': 3,
#          '沒肉': 1,
#          '得': 2,
#          '享受': 1,
#          '年前': 2,
#          '首度': 2,
#          '品嚐': 1,
#          '素肉': 1,
#          '海鮮': 2,
#          '至今': 2,
#          '仍': 4,
#          '樂在其中': 1,
#          '得宜': 1,
#          '既': 3,
#          '展現': 2,
#          '飲食文化': 1,
#          '符合': 3,
#          '人口': 3,
#          '發展潛力': 1,
#          '跨國': 1,
#          '數據': 2,
#          '比較': 1,
#          'Finder': 1,
#          '資訊': 1,
#          '顯示': 12,
#          '14%': 1,
#          '成人': 1,
#          '720': 1,
#          '萬人': 1,
#          '採取': 1,
#          '無肉': 1,
#          '6.5%': 1,
#          '素食主義者': 1,
#          'vegetarians': 1,
#          '4.5%': 1,
#          '純素': 1,
#          '主義者': 1,
#          'vegans': 1,
#          '則占約': 1,
#          '2.5%': 1,
#          '王子': 1,
#          '封號': 1,
#          '龍為': 1,
#          '忠實': 1,
#          '傳達': 1,
#          '將重': 1,
#          '達': 1,
#          '數十': 1,
#          '公斤': 1,
#          '醬汁': 2,
#          '調味料': 1,
#          '自台灣': 1,
#          '運來': 1,
#          '揣摩': 1,
#          '偏好': 1,
#          '抵達': 2,
#          '嚴格': 1,
#          '實施': 1,
#          '3': 7,
#          '天': 1,
#          '清口': 1,
#          '同時': 4,
#          '親自': 1,
#          '選購': 1,
#          '所有': 2,
#          '食材': 2,
#          '並在': 2,
#          '登場': 1,
#          '前先': 1,
#          '餐館': 1,
#          '進行': 6,
#          '田野': 1,
#          '考察': 1,
#          '見證': 1,
#          '年輕': 3,
#          '世代': 2,
#          '葡萄酒': 1,
#          '搭配': 1,
#          '裹': 1,
#          '著': 3,
#          '濃稠': 1,
#          '油炸': 1,
#          '素料': 2,
#          '津津有味': 1,
#          '獲': 3,
#          '國內外': 1,
#          '獎項': 1,
#          '肯定': 1,
#          '數次': 1,
#          '受台灣': 1,
#          '之邀': 1,
#          '前往': 2,
#          '北美洲': 1,
#          '南美洲': 1,
#          '澳洲': 11,
#          '推展': 1,
#          '選擇': 1,
#          '大量': 2,
#          '運用': 1,
#          '熟悉': 2,
#          '番茄': 1,
#          '花椰菜': 1,
#          '醬料': 1,
#          '顧及': 1,
#          '西式': 1,
#          '講究': 1,
#          '善用': 2,
#          '原食材': 1,
#          '精神': 1,
#          '亞洲': 2,
#          '調味': 1,
#          '風格': 1,
#          '技法': 1,
#          '實務': 1,
#          '達成': 1,
#          '跨界': 1,
#          '融合': 1,
#          '推廣': 2,
#          '類別': 1,
#          '高度': 1,
#          '共通性': 1,
#          '普遍性': 1,
#          '例如': 1,
#          '加入': 1,
#          '檸檬': 1,
#          '葉': 1,
#          '除了': 4,
#          '增添': 1,
#          '層次': 1,
#          '東亞': 1,
#          '南洋': 1,
#          '香料': 1,
#          '風味': 1,
#          '考量': 1,
#          '永續': 2,
#          '提到': 2,
#          '美味': 1,
#          '原則': 1,
#          '可以': 3,
#          '媒介': 1,
#          '發布': 4,
#          '戰略': 3,
#          '檢討': 1,
#          '報告': 13,
#          '建議': 2,
#          '第二次世界大戰': 2,
#          '大規模': 4,
#          '策略': 1,
#          '調整': 1,
#          '長程': 1,
#          '精準': 1,
#          '打擊': 1,
#          '國內': 1,
#          '導引': 1,
#          '武器': 1,
#          '列為': 1,
#          '優先': 1,
#          '事項': 1,
#          '這份': 6,
#          '不再': 2,
#          ...})

# %%
# 準備一個有經過stop word 處理的 counter
from collections import Counter
seg_stop_counter = Counter(seg_stop_words_list)
#seg_stop_counter

# %%
#有處理stop words
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate_from_frequencies(seg_stop_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("result.png")
plt.show()
plt.close()
